# %%
data = [
  "You are tasked with categorizing user complaints based on the provided definitions, category names, and subcategory names. Follow these instructions carefully:\n\nInput Constraints:\nUse only the definitions, category names, and subcategory names provided below.\nDo not infer or create new categories, subcategories, or definitions.\nClassify complaints strictly based on the provided information.\n\nClassification Rules:\nFor each user complaint, match it to the most relevant Category Name and Subcategory Name based on the definitions.\nIf no definition matches the complaint, respond with an error message.\n\nNote: Only use the given definitions, categories, and subcategories for matching. If a user complaint deviates or does not align, return the specified error message.\n\nDefinition:\nChild sexually abusive material (CSAM) refers to material containing sexual image in any form, of a child who is abused or sexually exploited. Section 67 (B) of IT Act states that “it is punishable for publishing or transmitting of material depicting children in sexually explicit act, etc. in electronic form.\nCatagory Name:\nWomen/Child Related Crime\nSubcategory Name:\nChild Pornography/Child Sexual Abuse Material (CSAM)\n\nDefinition:\nCredit card (or debit card) fraud involves an unauthorized use of another's credit or debit card information for the purpose of purchases or withdrawing funds from it.\nCatagory Name:\nFinancial Fraud Crimes\nSubcategory Name:\nDebit/Credit Card Fraud\n\nDefinition:\nSIM Swap Scam occurs when fraudsters manage to get a new SIM card issued against a registered mobile number fraudulently through the mobile service provider. With the help of this new SIM card, they get One Time Password (OTP) and alerts, required for making financial transactions through victim's bank account. Getting a new SIM card against a registered mobile number fraudulently is known as SIM Swap.\nCatagory Name:\t\nOther Cyber Crime\nSubcategory Name:\nSIM Swap Fraud\n\nDefinition:\nVishing is an attempt where fraudsters try to seek personal information like Customer ID, Net Banking password, ATM PIN, OTP, Card expiry date, CVV etc. through a phone call.\nCatagory Name:\t\nFinancial Fraud Crimes\nSubcategory Name:\nInternet Banking-Related Fraud\n\nDefinition:\t\nVishing is an attempt where fraudsters try to seek personal information like Customer ID, Net Banking password, ATM PIN, OTP, Card expiry date, CVV etc. through a phone call.\nCatagory Name:\t\nOther Cyber Crime\nSubcategory Name:\nFraud Call/Vishing\n\nDefinition:\t\nImpersonation and identity theft is an act of fraudulently or dishonestly making use of the electronic signature, password or any other unique identification feature of any other person.\nCatagory Name:\t\nOther Cyber Crime\t\nSubcategory Name:\nCheating by Impersonation\n\nDefinition:\t\nImpersonation and identity theft is an act of fraudulently or dishonestly making use of the electronic signature, password or any other unique identification feature of any other person.\nCatagory Name:\t\nOther Cyber Crime\t\nSubcategory Name:\nFake/Impersonating Profile\n\nDefinition:\t\nImpersonation and identity theft is an act of fraudulently or dishonestly making use of the electronic signature, password or any other unique identification feature of any other person.\t\nCatagory Name:\t\nOther Cyber Crime\t\nSubcategory Name:\nProfile Hacking/Identity Theft\n\nDefinition:\t\nOnline Job Fraud is an attempt to defraud people who are in need of employment by giving them a false hope/ promise of better employment with higher wages.\nCatagory Name:\t\t\nFinancial Fraud Crimes\t\nSubcategory Name:\nOnline Job Fraud\n\nDefinition:\nImpersonation and identity theft is an act of fraudulently or dishonestly making use of the electronic signature, password or any other unique identification feature of any other person.\t\nCatagory Name:\t\t\nFinancial Fraud Crimes\nSubcategory Name:\t\nOnline Matrimonial Fraud\n\nDefinition:\nA form of harassment or bullying inflicted through the use of electronic or communication devices such as computer, mobile phone, laptop, etc.\t\nCatagory Name:\t\t\nOther Cyber Crime\t\nSubcategory Name:\nCyber Bullying/Stalking/Sexting\n\nDefinition:\nWebsite Defacement is an attack intended to change visual appearance of a website and/ or make it dysfunctional. The attacker may post indecent, hostile and obscene images, messages, videos, etc.\t\nCatagory Name:\t\t\nOther Cyber Crime\nSubcategory Name:\t\nDefacement/Hacking\n\nDefinition:\nA data breach is an incident in which information is accessed without authorization.\t\nCatagory Name:\t\t\nOther Cyber Crime\nSubcategory Name:\t\nUnauthorized Access/Data Breach\n\nDefinition:\nRansomware is a type of computer malware that encrypts the files, storage media on communication devices like desktops, Laptops, Mobile phones etc., holding data/information as a hostage. The victim is asked to pay the demanded ransom to get his device decrypts.\t\nCatagory Name:\t\t\nOther Cyber Crime\nSubcategory Name:\t\nRansomware\n\nDefinition:\nEspionage is the act or practice of obtaining data and information without the permission and knowledge of the owner.\nCatagory Name:\t\t\nOther Cyber Crime\t\nSubcategory Name:\t\nUnauthorised Access to IT Systems/Data\t\n\nDefinition:\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\"Computer Virus is a program written to enter to your computer and damage/alter your files/data and replicate themselves.Worms are malicious programs that make copies of themselves again and again on the local drive, network shares, etc.A Trojan horse is not a virus. It is a destructive program that looks as a genuine application. Unlike viruses, Trojan horses do not replicate themselves but they can be just as destructive. Trojans open a backdoor entry to your computer which gives malicious users/programs access to your system, allowing confidential and personal information to be theft.\"\t\nCatagory Name:\t\nOther Cyber Crime\nSubcategory Name:\t\t\nMalicious Code Attacks\n\nDefinition:\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\"Denial of Services (DoS) attack is an attack intended for denying access to computer resource without permission of the owner or any other person who is in-charge of a computer, computer system or computer network.A Distributed Denial of Service (DDoS) attack is an attempt to make an online service unavailable by overwhelming it with traffic from multiple sources.\"\nCatagory Name:\t\t\nOther Cyber Crime\nSubcategory Name:\t\t\nDenial of Service (DoS) and Distributed Denial of Service (DDoS) Attacks\t\n\nDefinition:\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\nA data breach is an incident in which information is accessed without authorization.\t\nCatagory Name:\t\nOther Cyber Crime\t\nSubcategory Name:\t\nData Breaches\n\nDefinition:\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\nComputer Virus is a program written to enter to your computer and damage/alter your files/data and replicate themselves.Worms are malicious programs that make copies of themselves again and again on the local drive, network shares, etc.A Trojan horse is not a virus. It is a destructive program that looks as a genuine application. Unlike viruses, Trojan horses do not replicate themselves but they can be just as destructive. Trojans open a backdoor entry to your computer which gives malicious users/programs access to your system, allowing confidential and personal information to be theft.\nCatagory Name:\t\nOther Cyber Crime\t\nSubcategory Name:\t\nMalware attacks\t\t\n\nDefinition:\nWebsite Defacement is an attack intended to change visual appearance of a website and/ or make it dysfunctional. The attacker may post indecent, hostile and obscene images, messages, videos, etc.\t\nCatagory Name:\t\nOther Cyber Crime\t\nSubcategory Name:\t\nDefacement of Websites or Unauthorized Changes\n\nDefinition:\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\nIdentity theft is an act of fraudulently or dishonestly making use of the electronic signature, password or any other unique identification feature of any other person. and Phishing is a type of fraud that involves stealing personal information such as Customer ID, IPIN, Credit/Debit Card number, Card expiry date, CVV number, etc. through emails that appear to be from a legitimate source.\t\nCatagory Name:\t\nFinancial Fraud Crimes\t\nSubcategory Name:\t\nIdentity Theft, Spoofing, and Phishing Attacks\t\n\nDefinition:\t\ncommits rape, shall be punished with rigorous imprisonment of either description for a term which shall not be less than ten years, but which may extend to imprisonment for life, and shall also be liable to fine.Where a woman is raped by one or more persons constituting a group or acting in furtherance of a common intention, each of those persons1 shall be deemed to have committed the offence of rape and shall be punished with rigorous imprisonment for a term which shall not be less than twenty years, but which may extend to life which shall mean imprisonment for the remainder of that person’s natural life, and with fine\nCatagory Name:\t\nWomen/Child Related Crime\t\nSubcategory Name:\nRape/Gang Rape-Sexually Abusive Content\n\nDefinition:\t\nThe word “illegal” is applicable to everything which is an offence or which is prohibited by law, or which furnishes ground for a civil action; and a person is said to be “legally bound to do” whatever it is illegal in him to omit.\nCatagory Name:\t\nOther Cyber Crime\nSubcategory Name:\nDamage to Computer Systems\n\nDefinition:\nprovocation to any person intending or knowing it to be likely that such provocation will cause the offence of rioting to be committed, shall, if the offence of rioting be committed in consequence of such provocation, be punished with imprisonment of either description for a term which may extend to one year, or with fine, or with both; and if the offence of rioting be not committed, with imprisonment of either description for a term which may extend to six months, or with fine, or with both.\nCatagory Name:\t\nOther Cyber Crime\nSubcategory Name:\nProvocative Speech of Unlawful Acts\n\nDefinition:\nWhere a body corporate, possessing, dealing or handling any sensitive personal data or information in a computer resource which it owns, controls or operates, is negligent in implementing and maintaining reasonable security practices and procedures and thereby causes wrongful loss or wrongful gain to any person, such body corporate shall be liable to pay damages by way of compensation to the person so affected.\nCatagory Name:\t\nOther Cyber Crime\nSubcategory Name:\nUnauthorized Access to Social Media Accounts\n\n\n\nFor each user complaint provided, classify the definition into the appropriate Category Name and Subcategory Name. If the definition does not match any given example, respond with an error message.\noutput:\n{\n\"user compliant\" : \"get the user compliant\"\n\"Catagory Name\" : \"identified catagory name\",\n\"Subcategory Name\" :\"identified subcatagory name\"\n}\n\noutput:\n{\n\"error\":\"unable to identify\"\n}",
  "input: Hello please help me and more like me who are suffering financial frauds from these kinds of applications. I only downloaded the app, and without my consent, they gave me a loan and credited the amount into my account. They are asking for payment even after I’ve paid, and there’s no update in the application. They’ve accessed my contacts and are threatening to call them. I’m frustrated and need help.",
  "output: ```json\n{\n  \"error\": \"unable to identify\"\n}\n```",
  "input: I had continue received random calls and abusive messages in my whatsapp Someone added my number in a unknown facebook group name with  Only Girls  and still getting calls from unknown numbers pls help me and sort out the issue  as soon as possible Thank you",
  "output: ```json\n{\n  \"user complaint\": \"I had continue received random calls and abusive messages in my whatsapp Someone added my number in a unknown facebook group name with  Only Girls  and still getting calls from unknown numbers pls help me and sort out the issue  as soon as possible Thank you\",\n  \"Category Name\": \"Other Cyber Crime\",\n  \"Subcategory Name\": \"Cyber Bullying/Stalking/Sexting\"\n}\n```",
  "input: \"The above fraudster is continuously messaging me and Asking me to pay him money or he will send fake  cropped nude photos of me to my other contacts through WhatsApp\n\nI am unaware how he has recieved my contacts list from my phone\n\nPlease help\"",
  "output: ```json\n{\n  \"user complaint\": \"The above fraudster is continuously messaging me and Asking me to pay him money or he will send fake  cropped nude photos of me to my other contacts through WhatsApp\\n\\nI am unaware how he has recieved my contacts list from my phone\\n\\nPlease help\",\n  \"Category Name\": \"Other Cyber Crime\",\n  \"Subcategory Name\": \"Cyber Bullying/Stalking/Sexting\"\n}\n```",
  "input: In apna Job I have applied for job interview for telecalling and the resource management wrote that twelve hundred will be charged for security amount of laptop and work from home when I have given interview on the given address next day they charged twelve hundred and six hundred more money in the name of insurance after that they have referred me to the job calling there is no work of laptop neither a work from home kindly please take action against it as soon as possible and if possible please help me to recover my financial loss",
  "output: ```json\n{\n  \"user complaint\": \"In apna Job I have applied for job interview for telecalling and the resource management wrote that twelve hundred will be charged for security amount of laptop and work from home when I have given interview on the given address next day they charged twelve hundred and six hundred more money in the name of insurance after that they have referred me to the job calling there is no work of laptop neither a work from home kindly please take action against it as soon as possible and if possible please help me to recover my financial loss\",\n  \"Category Name\": \"Financial Fraud Crimes\",\n  \"Subcategory Name\": \"Online Job Fraud\"\n}\n```",
  "input: I received a call from lady stating that she will send new phone of vivo and I received that parcel through post on  th February to Kurnool head post office  where I have not received any mobile",
  "output: ```json\n{\n  \"error\": \"unable to identify\"\n}\n```",
  "input: \"FRAUD \t UPI PAYTM \nBANK \tPunjab National Bank including Oriental Bank of Commerce and United Bank of India\t\nACCOUNT NUMBER  \nTOTAL AMOUNT  \nPLEASE HOLD REVERSE TOTAL AMOUNT IN THE COMPLAINT ACCOUNT AND TAKE NECESSARY ACTION\n\"",
  "output: ```json\n{\n  \"error\": \"unable to identify\"\n}\n```",
  "input: FINANCIAL FRAUD  RS",
  "output: ```json\n{\n  \"error\": \"unable to identify\"\n}\n```",
  "input: I got the message on Whatsapp to my number The message contains very abusive words This message also includes my friend name and his number in that The same message was forwarded to all other friends also For more details please look into the file attached here Please take action ASAP",
  "output: ```json\n{\n  \"user complaint\": \"I got the message on Whatsapp to my number The message contains very abusive words This message also includes my friend name and his number in that The same message was forwarded to all other friends also For more details please look into the file attached here Please take action ASAP\",\n  \"Category Name\": \"Other Cyber Crime\",\n  \"Subcategory Name\": \"Cyber Bullying/Stalking/Sexting\"\n}\n```",
  "input: Details entered in pdf file Person posing as Army officer msg us that he want our place on rent and for that to confirm the account he wants us to transfer Re  in his account and once confirmed he will transfer back",
  "output: ```json\n{\n  \"user complaint\": \"Details entered in pdf file Person posing as Army officer msg us that he want our place on rent and for that to confirm the account he wants us to transfer Re  in his account and once confirmed he will transfer back\",\n  \"Category Name\": \"Financial Fraud Crimes\",\n  \"Subcategory Name\": \"Online Matrimonial Fraud\"\n}\n```",
  "input: I received a Whatsapp number in Happn Dating app Then I texted in Whatsapp after that they did a video call asked me to show the face I did then asked me to remove my clothes I did After that they recorded those videos and asking for me to send money I sent  again they are asking me  Kindly help me in this situation Also if needed i can come in person to meet and give more details Please Help",
  "output: ```json\n{\n  \"user complaint\": \"I received a Whatsapp number in Happn Dating app Then I texted in Whatsapp after that they did a video call asked me to show the face I did then asked me to remove my clothes I did After that they recorded those videos and asking for me to send money I sent  again they are asking me  Kindly help me in this situation Also if needed i can come in person to meet and give more details Please Help\",\n  \"Category Name\": \"Other Cyber Crime\",\n  \"Subcategory Name\": \"Cyber Bullying/Stalking/Sexting\"\n}\n```",
  "input: Someone changed my email id nd contact number by using anydesk app nd now he had ordered  k product from my account through emi my contact number is nd he changed to this number nd email id also hve been changed now he have access to my account",
  "output: ```json\n{\n  \"user complaint\": \"Someone changed my email id nd contact number by using anydesk app nd now he had ordered  k product from my account through emi my contact number is nd he changed to this number nd email id also hve been changed now he have access to my account\",\n  \"Category Name\": \"Other Cyber Crime\",\n  \"Subcategory Name\": \"Profile Hacking/Identity Theft\"\n}\n```",
  "input: I have a friend with whom I made deal to exchange my gaming account of BGMI and he found an account as well for exchange So I shared my login details with him to check the inventory available in my account Suddenly I received a mail that my email id has been changed When I tried contacting him he blocked my call and when I tried calling on WhatsApp he is not answering the call I have spent more than Rs  in my gaming account Request you to please regain my account",
  "output: ```json\n{\n  \"user complaint\": \"I have a friend with whom I made deal to exchange my gaming account of BGMI and he found an account as well for exchange So I shared my login details with him to check the inventory available in my account Suddenly I received a mail that my email id has been changed When I tried contacting him he blocked my call and when I tried calling on WhatsApp he is not answering the call I have spent more than Rs  in my gaming account Request you to please regain my account\",\n  \"Category Name\": \"Other Cyber Crime\",\n  \"Subcategory Name\": \"Profile Hacking/Identity Theft\"\n}\n```",
  "input: \"\n\nFRAUD THROUGH DebitCredit Card FraudSim Swap Fraud\t\n\nBANKAirtel Payments Bank\t\n     \nACCOUNT NO \n\nTOTAL AMOUNT\t\t \t\n \t\nPLEASE HOLD REVERSE TOTAL AMOUNT IN THE COMPLAINT ACCOUNT AND TAKE NECESSARY ACTION\n\n\n\"",
  "output: ```json\n{\n  \"user complaint\": \"FRAUD THROUGH DebitCredit Card FraudSim Swap Fraud\\n\\nBANKAirtel Payments Bank\\n     \\nACCOUNT NO \\n\\nTOTAL AMOUNT\t\t \t\\n \t\\nPLEASE HOLD REVERSE TOTAL AMOUNT IN THE COMPLAINT ACCOUNT AND TAKE NECESSARY ACTION\",\n  \"Category Name\": \"Financial Fraud Crimes\",\n  \"Subcategory Name\": \"Debit/Credit Card Fraud\"\n}\n```",
  "input: Received Call from unknown person claimed to be related to his father and said that he had borrowed rs  from his father and want to refund first he confirmed account by sending rs  their after he has theft rs  by  transaction of rs  each call receved from mobile no",
  "output: ```json\n{\n  \"user complaint\": \"Received Call from unknown person claimed to be related to his father and said that he had borrowed rs  from his father and want to refund first he confirmed account by sending rs  their after he has theft rs  by  transaction of rs  each call receved from mobile no\",\n  \"Category Name\": \"Financial Fraud Crimes\",\n  \"Subcategory Name\": \"Internet Banking-Related Fraud\"\n}\n```",
  "input: \"FRAUD THROUGH UPI Phone Pe\nBANK BARODA UP GRAMIN BANK\nACCOUNT NUMBER \nTOTAL AMOUNT \nPLEASE HOLDREVERSE TOTAL AMOUNT IN THE COMPLAINT ACCOUNT AND TAKE NECESSARY ACTION \"",
  "output: ```json\n{\n  \"error\": \"unable to identify\"\n}\n```",
  "input: I wanted to sell my cot on Quikr This person named Ankit Sharma Shop was Interested I am new to Googlepay Voucher payment and he sent me a voucher to pay the amount to my account but the transaction was reverse and he got paid the amount",
  "output: ```json\n{\n  \"user complaint\": \"I wanted to sell my cot on Quikr This person named Ankit Sharma Shop was Interested I am new to Googlepay Voucher payment and he sent me a voucher to pay the amount to my account but the transaction was reverse and he got paid the amount\",\n  \"Category Name\": \"Financial Fraud Crimes\",\n  \"Subcategory Name\": \"Internet Banking-Related Fraud\"\n}\n```",
  "input: R sir someone call me from  and said that he is my known JAGDISH  and he said some money on my mobile googlepay after that he said a link on my googlpay on rupees  then i click on this link the money is deducted form my account so please solve the same asap",
  "output: ```json\n{\n  \"user complaint\": \"R sir someone call me from  and said that he is my known JAGDISH  and he said some money on my mobile googlepay after that he said a link on my googlpay on rupees  then i click on this link the money is deducted form my account so please solve the same asap\",\n  \"Category Name\": \"Financial Fraud Crimes\",\n  \"Subcategory Name\": \"Internet Banking-Related Fraud\"\n}\n```",
  "input: I lost amount of  lakh  hazaar rupees",
  "output: ```json\n{\n  \"error\": \"unable to identify\"\n}\n```",
  "input: i received are message from cell no  that my SBI YONO Account has been suspended and to update your PAN card immediately and given a link httspsbipanuponlinepreviewdomaincom at hours according the the link i activate and at result an amount of Rs taken my account pls take necessary action and get my money",
  "output: ```json\n{\n  \"user complaint\": \"i received are message from cell no  that my SBI YONO Account has been suspended and to update your PAN card immediately and given a link httspsbipanuponlinepreviewdomaincom at hours according the the link i activate and at result an amount of Rs taken my account pls take necessary action and get my money\",\n  \"Category Name\": \"Financial Fraud Crimes\",\n  \"Subcategory Name\": \"Identity Theft, Spoofing, and Phishing Attacks\"\n}\n```",
  "input: The issue actually started when I got this email, which at first glance seemed like spam. I usually ignore such things, but for some reason, I opened it this time. Afterward, my phone started freezing, and it wasn’t normal. I thought it was a technical glitch, but now I’m not so sure. Honestly, it’s such a mess, and I don’t even know where to start. I’ve contacted support, but they keep giving me the runaround. The more I tried to fix it, the more problems came up. My bank account was notifiction, and then I got locked out of everything. The worst part is, I don’t even know who to trust anymore. Friends, family, everyone’s acting strange. It’s affecting my relationships and my mental health. Even my laptop isn’t working right anymore. It’s so stange how everything just fell apart after that one email.",
  "output: ```json\n{\n  \"user complaint\": \"The issue actually started when I got this email, which at first glance seemed like spam. I usually ignore such things, but for some reason, I opened it this time. Afterward, my phone started freezing, and it wasn’t normal. I thought it was a technical glitch, but now I’m not so sure. Honestly, it’s such a mess, and I don’t even know where to start. I’ve contacted support, but they keep giving me the runaround. The more I tried to fix it, the more problems came up. My bank account was notifiction, and then I got locked out of everything. The worst part is, I don’t even know who to trust anymore. Friends, family, everyone’s acting strange. It’s affecting my relationships and my mental health. Even my laptop isn’t working right anymore. It’s so stange how everything just fell apart after that one email.\",\n  \"Category Name\": \"Other Cyber Crime\",\n  \"Subcategory Name\": \"Malware attacks\"\n}\n```",
  "input: \"Regarding job vacancies they call me and ask the money for processing fees including this I share the details of the person whos contact me \n Amen verma   \n Nithin   \n Sachin   \"",
  "output: ```json\n{\n  \"user complaint\": \"Regarding job vacancies they call me and ask the money for processing fees including this I share the details of the person whos contact me \\n Amen verma   \\n Nithin   \\n Sachin   \",\n  \"Category Name\": \"Financial Fraud Crimes\",\n  \"Subcategory Name\": \"Online Job Fraud\"\n}\n```",
  "input: \"Respected Cyber crime Ghatkopar east Mumbai\n\n\nThis is Irshad Gafur Shaikh I reside in Ghatkopar east with my family and i am responsible citizen of India and my family\n\n\nI would like to highlight you about two fruadulant loan app which are quitely robbing to innocent and family responsible people like me\n\n\n Koko loan\n\nI was looking for k then filling my personal details it showed k then i clicked to check tenurity and roi\n\nIt directly selected as applied itself and credited into my account of Rs  and repayment amount is showing as k with  days tenurity\n\nScreen shots shared for your reference\n\n AG Loan\n\nI was looking for k loan as per the app given limit for  days tenurity and i applied for the same then next it credited rs  into my bank account as showing repayment of k with  days tenurity\n\nScreen shots and recording shared for your reference\n\nNone of the above have mentioned contact center or points\n\nI tried to contact them also however its all scam\n\n\nI heartly request you to help me out from the same\n\nI am from middle class and i already having many family responaiblity\n\nI am ready for the same credited amount only but they are not acknowledging that\"",
  "output: ```json\n{\n  \"error\": \"unable to identify\"\n}\n```",
  "input: I never imagined something like this could happen to me, especially since I'm so cautious. But then I started noticing that my online activity felt different, slower even. I can't even describe it well because everything seemed normal, except for the fact that I was constantly getting logged out of my accounts. I don't know how, but it’s like they knew everything I was doing, even though I was trying to be careful. It’s terrifying to think about. The more I tried to fix it, the more problems came up. My email was hackd, and then I got locked out of everything. I don’t think I’ve ever felt this violated before. My privacy is completely shattered, and I can’t do anything to make it stop. Even my laptop isn’t working right anymore. It’s so stange how everything just fell apart after that one email.",
  "output: ```json\n{\n  \"user complaint\": \"I never imagined something like this could happen to me, especially since I'm so cautious. But then I started noticing that my online activity felt different, slower even. I can't even describe it well because everything seemed normal, except for the fact that I was constantly getting logged out of my accounts. I don't know how, but it’s like they knew everything I was doing, even though I was trying to be careful. It’s terrifying to think about. The more I tried to fix it, the more problems came up. My email was hackd, and then I got locked out of everything. I don’t think I’ve ever felt this violated before. My privacy is completely shattered, and I can’t do anything to make it stop. Even my laptop isn’t working right anymore. It’s so stange how everything just fell apart after that one email.\",\n  \"Category Name\": \"Other Cyber Crime\",\n  \"Subcategory Name\": \"Unauthorized Access/Data Breach\"\n}\n```",
  "input: \"Respected Sir\n\nA very serious matter I want to inform you Few person running or involve in some very shamefull activities by using few women at many places of kolkata gariahat ballygunge RUBY HOSPITAL BEHIND area KASBA ANANDAPUR QUEST MALL metropolis mall area ACROPOLISMALL area park circus FORUM MALL ELGIN RD Parkstreet MAIDAN AREA esplanade Garia jadavpur BEHALASAKHERBAZAR JOKA BANSDRONI  Rabindrasadanexide area  HARIDEVPUR triangular park lake mall area rashbehari area TOLLYGUNGE THAKURPUKUR BBD BAG DALHOUSIE AREA  and SALTLAKE\n\nTheir name \nSUBHRO SAHA AMLAN DATTA \nIZAZ AHMED Anirban\n\n\nThey officially work in a insurance office hdfclife  a hindustanpark ab gariahat shopping mall st floor beside of reliance trend building near gariahat more  but outside at several places  they involve in some shamefull activities last years\n\nSir a person SUBHRO SAHA forcefully involve few women employee ex FEMALE employee in such shamefull doing\n\nAt afternoon evening or after evening or night time they doing this shamefull activities\n\nMany innocent people are TRAPPED and suffering in such dirty issue for long time\nThey are even  to lodge a complain against them because of  threatening and blackmailing ISSUE\n\n\nFrom above  address PLACES and their mobile whatsapp no  you can easily trace and track their all activities You need to investigate Last years detail\n\n\nPlease help\"",
  "output: ```json\n{\n  \"error\": \"unable to identify\"\n}\n```",
  "input: Online job fraud victim received a link related to online job goes to payment page for processing fee otp entered amount lost cheated Suspect no httpsquikrjobssite",
  "output: ```json\n{\n  \"user complaint\": \"Online job fraud victim received a link related to online job goes to payment page for processing fee otp entered amount lost cheated Suspect no httpsquikrjobssite\",\n  \"Category Name\": \"Financial Fraud Crimes\",\n  \"Subcategory Name\": \"Online Job Fraud\"\n}\n```",
  "input: Stop that like fruod for any body do not sher your otp and other ccvcard numberwith other do not resive new number callcastomer family member ferinds with any person do not sher otip and cvv number do not follow any instructions  for calls massages  linkes or other related questions inform the public about  no cheating",
  "output: ```json\n{\n  \"error\": \"unable to identify\"\n}\n```",
  "input: RUPAY KA RECHAREGE PHONE PE SE KARNE KE  UPRANT THODI DER BAD ACCOUNT SE PASE KAT CHUKE THE MESSAGE DWARA PATA CHALA   KAT GYE THE  SE  FEB  BANK BAND HONE SE KO SUCHIT NAHI KARA PYE  FEB KO BANK KO APPLICATION DWARA SUCHIT KIYA   TO YE PASE KAT KARKE GALTI SE NIKALE GAYE HAI KRIPYA ISKI SAHI JACH KAR ACCOUNT ME PASE LAUTANE KI KRIPA KARE",
  "output: ```json\n{\n  \"error\": \"unable to identify\"\n}\n```",
  "input: Hello please help me and more like me who are suffering financial frauds from these kind of applications I only downloaded the app without my consent they gave me loan of  and credited amount  in my account for only  days they are asking for payment of  and even now i had done my payment still no update is done in application still showing for payment and the customer who was earlier taalking to me on whatsapp now has switched off  her phone and they have accessed all my contacts and are threatning me to call them I am too much frustated please help this is the last hope from you all and i tried everywhere but i didnt get any response from any source since the payment is not showing in qpplicatun they will ask for bounce charge and threaten me to callplease look into the matter not only me is trapped in this there could be number of poor persons like me So at last please help",
  "output: ```json\n{\n  \"error\": \"unable to identify\"\n}\n```",
  "input: \"Sir\n\nI have invested around  lakh in these app from  they are very smart and initially keep their payment system clean with no doubt and from  they creating problem in payments Please help\"",
  "output: ```json\n{\n  \"error\": \"unable to identify\"\n}\n```",
  "input: This is an unauthorized transaction from an international website Vimeocom I did not receive any prior intimation or authorization mail or notification for the transaction I have blocked the card and raised a complaint with the bank authorities as well Please help",
  "output: ```json\n{\n  \"user complaint\": \"This is an unauthorized transaction from an international website Vimeocom I did not receive any prior intimation or authorization mail or notification for the transaction I have blocked the card and raised a complaint with the bank authorities as well Please help\",\n  \"Category Name\": \"Financial Fraud Crimes\",\n  \"Subcategory Name\": \"Debit/Credit Card Fraud\"\n}\n```",
  "input: A call from    this number was received by me  saying that speaking from indusind bank helping me to make credit card  I received a call at  pm first a lady was speaking then the call was transferred by them to another person  the were having a fake url website made by them only  They make me to open the site and told me to fill the details  i did so  they said that a  rupees otp will come to me as a charges of card  they said a virtual card will be generated of  rupees but the virtual card was not generated they asked me to fill the card number again then  the amount was deducted from my card of  approximately",
  "output: ```json\n{\n  \"user complaint\": \"A call from    this number was received by me  saying that speaking from indusind bank helping me to make credit card  I received a call at  pm first a lady was speaking then the call was transferred by them to another person  the were having a fake url website made by them only  They make me to open the site and told me to fill the details  i did so  they said that a  rupees otp will come to me as a charges of card  they said a virtual card will be generated of  rupees but the virtual card was not generated they asked me to fill the card number again then  the amount was deducted from my card of  approximately\",\n  \"Category Name\": \"Financial Fraud Crimes\",\n  \"Subcategory Name\": \"Debit/Credit Card Fraud\"\n}\n```",
  "input: we received call from salomi saying she is custom officer in mumbai one more person is also invoved joshil patel from usa  he was also involved in this they both have created scam for me and looted from me  as an custom duty joshil patel introduced me as my old friend from school he said i will send you some small gift as a friendship we thought its the same parcel but the are now creating story and nobody is giving us details of the parcel its a complete fraud please helo us",
  "output: ```json\n{\n  \"error\": \"unable to identify\"\n}\n```",
  "input: \"FRAUD THROUGH UPI PHONE PE \nBANK  STATE BANK OF INDIA \nACCOUNT NUMBER  \nTOTAL AMOUNT   \nPLEASE HOLD  REVERSE TOTAL AMOUNT IN THE COMPLAINT ACCOUNT AND TAKE NECESSARY ACTION\n\n\"",
  "output: ```json\n{\n  \"error\": \"unable to identify\"\n}\n```",
  "input: \"Citizen Details \nAddress   Name  BHAGCHAND SAINI  MOBILE NO    DIST  DAUSA    PS SIKANDRA    EMAIL ID  bhagchandmaligmailcom  PINCODE      BANK  STATE BANK OF INDIA AC NO    BRANCH  BHANDARANGE  Citizen Ke sath  Total Fraud Amount   Rs   DATE Jan\n\nFraud By    Phone Pay No \n Transction id  T  UTR      Amount Rs   TIME   PM \nFrauder Detals  Suchna karta ne bataya ki unke pass unhone no   se call aaya or jankar bankar ki baat ki or paise transfer karva liye \"",
  "output: ```json\n{\n  \"user complaint\": \"Citizen Details \\nAddress   Name  BHAGCHAND SAINI  MOBILE NO    DIST  DAUSA    PS SIKANDRA    EMAIL ID  bhagchandmaligmailcom  PINCODE      BANK  STATE BANK OF INDIA AC NO    BRANCH  BHANDARANGE  Citizen Ke sath  Total Fraud Amount   Rs   DATE Jan\\n\\nFraud By    Phone Pay No \\n Transction id  T  UTR      Amount Rs   TIME   PM \\nFrauder Detals  Suchna karta ne bataya ki unke pass unhone no   se call aaya or jankar bankar ki baat ki or paise transfer karva liye \",\n  \"Category Name\": \"Financial Fraud Crimes\",\n  \"Subcategory Name\": \"Internet Banking-Related Fraud\"\n}\n```",
  "input: \"FRAUD THROUGH  UPI PHONE PE \n BANK  UCO BANK \n ACCOUNT NUMBER  \n TOTAL AMOUNT  \n PLEASE HOLD REVERSE TOTAL AMOUNT IN THE COMPLAINT ACCOUNT AND TAKE         NECESSARY ACTION\"",
  "output: ```json\n{\n  \"error\": \"unable to identify\"\n}\n```",
  "input: \"FRAUD THROUGH UPI FRAUD GOOGLE PAY\nBANK  BANK OF BARODA\nACCOUNT NUMBER  \nTOTAL AMOUNT   \n\nPLEASE HOLD  REVERSE TOTAL AMOUNT IN THE COMPLAINT ACCOUNT AND TAKE NECESSARY ACTION\"",
  "output: ```json\n{\n  \"error\": \"unable to identify\"\n}\n```",
  "input: \"Online Frauds   Gaming Fraud  Any Other\nvictim paid some amount for free fire game access id so later he came to know that it was a fraud\"",
  "output: ```json\n{\n  \"user complaint\": \"Online Frauds   Gaming Fraud  Any Other\\nvictim paid some amount for free fire game access id so later he came to know that it was a fraud\",\n  \"Category Name\": \"Financial Fraud Crimes\",\n  \"Subcategory Name\": \"Online Job Fraud\"\n}\n```",
  "input: \"httpswwwxnxxtvvideousapbfuckkkarrr\n\n Above link is correct video URl she is one of our relative \n\nPlease help her now she is going to get marry other person they are not aware of this information while its recording some malwere functionality has recorded without their permission \n\nPlease help her and remove the above video\"",
  "output: ```json\n{\n  \"error\": \"unable to identify\"\n}\n```",
  "input: His name is Avaneesh Parasar staying in Patna at FLAT   RANJAN PALACE MAGISTRATE COLONY ASHIYANA DIGHA ROAD POST AASHIYANA NAGAR THANA RAJIV NAGAR DIS  PATNA PIN CODE  He took crores of rupees from thousands on people all over india for trading in Bitcoin and promised to return with profit  Capital amount but now he is not returning and arguing and using slangs when we are asking for our own money We are figiting with him from  with him and everytime he keeps giving the reason for each and everything and keeps figting for not retrning the money We are very tired of all this and need to catch him at the earliest Many people are not complaining due to scared of losing their money Even Avaneesh says frankly to complaint to police or move with legal action as police cant do anything to him it seems He is very confident about the police is not going to do anything to him We are struggling lot with him as he is not returning our amount atleast  Request you to spread awareness in media to save many people from him Along with him his partner Sanjana and Anjalli calling many people and inviting to join his online fraud business and they are taking many people money and not returning theier capital also People have to fight to get their own money from him now He also removed from FB group to those people from whomever he took money and not returning He created another new group on Facebook to trap new people and take the money Please catch him asap",
  "output: ```json\n{\n  \"error\": \"unable to identify\"\n}\n```",
  "input: caller has lost  rupees through fraud call",
  "output: ```json\n{\n  \"error\": \"unable to identify\"\n}\n```",
  "input: \"Payu payments pvt Ltd\nOnemobiwiksystem pvt Ltd  \nThese name show in dhany pay transcation  \n other nb that use my adhar card \nPlz resolve my problm\nHe mis use my wallet money\"",
  "output: ```json\n{\n  \"error\": \"unable to identify\"\n}\n```",
  "input: \"FRAUD THROUGH UPI \tFRAUD  PHONEPE  \nBANK  STATE OF INDIA \nACCOUNT NO     \nTOTAL AMOUNT \nPLEASE HOLD REVERSE TOTAL AMOUNT IN THE COMPLAINT ACCOUNT AND TAKE NECESSARY ACTION\"",
  "output: ```json\n{\n  \"error\": \"unable to identify\"\n}\n```",
  "input: \"FRAUD THROUGH UPI PHONEPE\nBANK SBI BANK \nACCOUNT NO  \nTOTAL\nPLEASE HOLD REVERSE TOTAL AMOUNT IN THE \nCOMPLAINT  ACCOUNT AND TAKE NECESSARY ACTION\n\"",
  "output: ```json\n{\n  \"error\": \"unable to identify\"\n}\n```",
  "input: Many fake accounts are created and Im suffering since year vulgar language chatting in Instagram with my friends and family members and they are also suffering by this issue in kindly requesting to you help me its my humble request",
  "output: ```json\n{\n  \"user complaint\": \"Many fake accounts are created and Im suffering since year vulgar language chatting in Instagram with my friends and family members and they are also suffering by this issue in kindly requesting to you help me its my humble request\",\n  \"Category Name\": \"Other Cyber Crime\",\n  \"Subcategory Name\": \"Fake/Impersonating Profile\"\n}\n```",
  "input: EMI",
  "output: ```json\n{\n  \"error\": \"unable to identify\"\n}\n```",
  "input: victime online lo olx flat form nandu pulsar bike konali ani search cheyaga fraud star  amount loss ayyaru",
  "output: ```json\n{\n  \"error\": \"unable to identify\"\n}\n```",
  "input: name  gaurav chhangani ne bataya ki mere google pe no  pe  ka link aaya jese hi mene uspe click  kiya mere BOB ac no  se  rupay kat gaye",
  "output: ```json\n{\n  \"user complaint\": \"name  gaurav chhangani ne bataya ki mere google pe no  pe  ka link aaya jese hi mene uspe click  kiya mere BOB ac no  se  rupay kat gaye\",\n  \"Category Name\": \"Financial Fraud Crimes\",\n  \"Subcategory Name\": \"Internet Banking-Related Fraud\"\n}\n```",
  "input: \"SirMaam \nThis is my third report on this reporting portal I had conflicts with my boyfriend ex where he caused problems to me and my family In the heat of the moment he threatened me that he will leak my private photos on the internet In the deep shock while I was searching internships on LinkedIn I came across a new account named Abhishek Sharma He manipulated me by reading my face and hand and i spilled the beans about the incident and told me that I was threatened regarding my private pics Though my ex boyfriend didnt do anything but i was mentally disturbed and still am Since December   he has been threatening me and my ex boyfriend that he has hacked his phone and he will leak our pictures He makes new instagram accounts he hacked my exs account he now emails me Alleged Abhishek Sharma also asked me to meet and said he wants my nudes \n\nPlease help me I can only provide you with instagram handles and his email I have no information about him but he has all information about me and my ex \n\nIts been more than two months now I dont want my family involved Please solve this \n\nHe has been calling from different number texting from different accounts hacking our social media accounts says that he has our nudes Please help\"",
  "output: ```json\n{\n  \"user complaint\": \"SirMaam \\nThis is my third report on this reporting portal I had conflicts with my boyfriend ex where he caused problems to me and my family In the heat of the moment he threatened me that he will leak my private photos on the internet In the deep shock while I was searching internships on LinkedIn I came across a new account named Abhishek Sharma He manipulated me by reading my face and hand and i spilled the beans about the incident and told me that I was threatened regarding my private pics Though my ex boyfriend didnt do anything but i was mentally disturbed and still am Since December   he has been threatening me and my ex boyfriend that he has hacked his phone and he will leak our pictures He makes new instagram accounts he hacked my exs account he now emails me Alleged Abhishek Sharma also asked me to meet and said he wants my nudes \\n\\nPlease help me I can only provide you with instagram handles and his email I have no information about him but he has all information about me and my ex \\n\\nIts been more than two months now I dont want my family involved Please solve this \\n\\nHe has been calling from different number texting from different accounts hacking our social media accounts says that he has our nudes Please help\",\n  \"Category Name\": \"Other Cyber Crime\",\n  \"Subcategory Name\": \"Cyber Bullying/Stalking/Sexting\"\n}\n```",
  "input: \"Sir I am Prabhat Singh jat  An app on playstore which name is rupeestarsago  I\nhave been never applied for a loan from this app  They copied my contact\nlist and asking for loan repayment they are calling my contacts and\nrelatives and abusing himher  They are mentally harrasing me Please\ntake strict action on this  They are defaming me infront of my contact and\nrelatives They are forced me to do suicide I am not able swith on my\nmobile phone they are calling continuously and abusing me  If this is not\nclosed i commit suiside\"",
  "output: ```json\n{\n  \"error\": \"unable to identify\"\n}\n```",
  "input: After recharging my RuPay card using PhonePe, I received a message a short while later stating that the money had been deducted from my account. However, the recharge was unsuccessful. Due to the bank being closed in February, I was unable to report this issue immediately. I filed a complaint with the bank in February, requesting that they investigate this incorrect deduction and refund the money to my account.",
  "output: ```json\n{\n  \"error\": \"unable to identify\"\n}\n```"
]

# %%
prompt = """You are an automated complaint classifier. Given a complaint description, your task is to classify it into one of the following *predefined categories and subcategories. **Do not classify complaints outside the specified categories*. If you are unable to classify the complaint, output "unable to identify" for both the category and subcategory. Carefully read the complaint and analyze its content to assign the most accurate category and subcategory.

*Strictly follow this output template*:
complain: [complaint description]
category: [Category Name] or "unable to identify"
subcategory: [Subcategory Name] or "unable to identify"

---

### *Categories and Subcategories:*

*1. Women/Child Related Crime:*
  - Child Pornography/Child Sexual Abuse Material (CSAM)
  - Rape/Gang Rape-Sexually Abusive Content
  - Sale, Publishing and Transmitting Obscene Material/Sexually Explicit Material

*2. Financial Fraud Crimes:*
  - Debit/Credit Card Fraud
  - SIM Swap Fraud
  - Internet Banking-Related Fraud
  - Business Email Compromise/Email Takeover
  - E-Wallet Related Frauds
  - Fraud Call/Vishing
  - Demat/Depository Fraud
  - UPI-Related Frauds
  - Aadhaar Enabled Payment System (AEPS) Fraud
  - Email Phishing
  - Cheating by Impersonation
  - Fake/Impersonating Profile
  - Profile Hacking/Identity Theft
  - Online Job Fraud
  - Online Matrimonial Fraud

*3. Other Cyber Crime:*
  - Cyber Bullying/Stalking/Sexting
  - Email Hacking
  - Damage to Computer Systems
  - Tampering with Computer Source Documents
  - Defacement/Hacking
  - Unauthorized Access/Data Breach
  - Online Cyber Trafficking
  - Online Gambling/Betting Fraud
  - Ransomware
  - Cryptocurrency Crime
  - Cyber Terrorism
  - Any Other Cyber Crime
  - Targeted scanning/probing of critical networks/systems
  - Compromise of critical systems/information
  - Unauthorised access to IT systems/data
  - Defacement of websites or unauthorized changes, such as inserting malicious code or external links
  - Malicious code attacks (e.g., virus, worm, Trojan, Bots, Spyware, Ransomware, Crypto miners)
  - Attacks on servers (Database, Mail, DNS) and network devices (Routers)
  - Identity theft, spoofing, and phishing attacks
  - Denial of Service (DoS) and Distributed Denial of Service (DDoS) attacks
  - Attacks on critical infrastructure, SCADA, operational technology systems, and wireless networks
  - Attacks on applications (e.g., E-Governance, E-Commerce)
  - Data breaches
  - Data leaks
  - Attacks on Internet of Things (IoT) devices and associated systems, networks, and servers
  - Attacks or incidents affecting digital payment systems
  - Attacks via malicious mobile apps
  - Fake mobile apps
  - Unauthorised access to social media accounts
  - Attacks or suspicious activities affecting cloud computing systems, servers, software, and applications
  - Attacks or malicious/suspicious activities affecting systems related to Big Data, Blockchain, virtual assets, and robotics
  - Attacks on systems related to Artificial Intelligence (AI) and Machine Learning (ML)
  - Backdoor attacks
  - Disinformation or misinformation campaigns
  - Supply chain attacks
  - Cyber espionage
  - Zero-day exploits
  - Password attacks
  - Web application vulnerabilities
  - Hacking
  - Malware attacks

---

### *Instructions*:

1. *Read and analyze* the complaint description *carefully. Understand the **context* and *details* of the complaint to accurately classify it.

2. *Classify* the complaint based on its content into one of the *predefined categories and subcategories* above.
   - *Do not classify complaints outside the provided categories and subcategories.* If you cannot identify the category and subcategory, output:
     - category: unable to identify
     - subcategory: unable to identify

3. *Strict Format: The output must follow the exact template below. **Do not deviate* from this format:



4. Ensure the category and subcategory you choose are *relevant* to the complaint and based on the *specific nature* of the complaint. *Do not generalize.*

---

### *Example Classifications:*
Example Classifications:
We have provided 50 sample examples below. Please read them carefully and try to gain insights into how complaints should be classified based on the category and subcategory. These examples represent a variety of cases, including fraud, cybercrime, and personal security issues.

1. Input:
Online job fraud victim received a link related to online job goes to payment page for processing fee otp entered amount lost cheated Suspect no httpsquikrjobssite
Output:


{
  "complain": "Online job fraud victim received a link related to online job goes to payment page for processing fee otp entered amount lost cheated Suspect no httpsquikrjobssite",
  "category": "Financial Fraud Crimes",
  "subcategory": "Online Job Fraud"
}
2. Input:
Stop that like fruod for any body do not sher your otp and other ccvcard numberwith other do not resive new number callcastomer family member ferinds with any person do not sher otip and cvv number do not follow any instructions for calls massages linkes or other related questions inform the public about no cheating
Output:

{
  "complain": "Stop that like fruod for any body do not sher your otp and other ccvcard numberwith other do not resive new number callcastomer family member ferinds with any person do not sher otip and cvv number do not follow any instructions for calls massages linkes or other related questions inform the public about no cheating",
  "category": "Financial Fraud Crimes",
  "subcategory": "Online Job Fraud"
}
3. Input:
RUPAY KA RECHAREGE PHONE PE SE KARNE KE UPRANT THODI DER BAD ACCOUNT SE PASE KAT CHUKE THE MESSAGE DWARA PATA CHALA KAT GYE THE SE FEB BANK BAND HONE SE KO SUCHIT NAHI KARA PYE FEB KO BANK KO APPLICATION DWARA SUCHIT KIYA TO YE PASE KAT KARKE GALTI SE NIKALE GAYE HAI KRIPYA ISKI SAHI JACH KAR ACCOUNT ME PASE LAUTANE KI KRIPA KARE
Output:


{
  "complain": "RUPAY KA RECHAREGE PHONE PE SE KARNE KE UPRANT THODI DER BAD ACCOUNT SE PASE KAT CHUKE THE MESSAGE DWARA PATA CHALA KAT GYE THE SE FEB BANK BAND HONE SE KO SUCHIT NAHI KARA PYE FEB KO BANK KO APPLICATION DWARA SUCHIT KIYA TO YE PASE KAT KARKE GALTI SE NIKALE GAYE HAI KRIPYA ISKI SAHI JACH KAR ACCOUNT ME PASE LAUTANE KI KRIPA KARE",
  "category": "Financial Fraud Crimes",
  "subcategory": "Online Job Fraud"
}



4. Input:
I lost amount of lakh hazaar rupees
Output:


{
  "complain": "I lost amount of lakh hazaar rupees",
  "category": "Financial Fraud Crimes",
  "subcategory": "Financial Fraud Crimes"
}

5. Input:
i received are message from cell no that my SBI YONO Account has been suspended and to update your PAN card immediately and given a link httspsbipanuponlinepreviewdomaincom at hours according the the link i activate and at result an amount of Rs taken my account pls take necessary action and get my money
Output:

{
  "complain": "i received are message from cell no that my SBI YONO Account has been suspended and to update your PAN card immediately and given a link httspsbipanuponlinepreviewdomaincom at hours according the the link i activate and at result an amount of Rs taken my account pls take necessary action and get my money",
  "category": "Financial Fraud Crimes",
  "subcategory": "Identity Theft, Spoofing, and Phishing Attacks"
}

6. Input:
The issue actually started when I got this email, which at first glance seemed like spam. I usually ignore such things, but for some reason, I opened it this time. Afterward, my phone started freezing, and it wasn’t normal. I thought it was a technical glitch, but now I’m not so sure. Honestly, it’s such a mess, and I don’t even know where to start. I’ve contacted support, but they keep giving me the runaround. The more I tried to fix it, the more problems came up. My bank account was notifiction, and then I got locked out of everything. The worst part is, I don’t even know who to trust anymore. Friends, family, everyone’s acting strange. It’s affecting my relationships and my mental health. Even my laptop isn’t working right anymore. It’s so stange how everything just fell apart after that one email.
Output:

{
  "complain": "The issue actually started when I got this email, which at first glance seemed like spam. I usually ignore such things, but for some reason, I opened it this time. Afterward, my phone started freezing, and it wasn’t normal. I thought it was a technical glitch, but now I’m not so sure. Honestly, it’s such a mess, and I don’t even know where to start. I’ve contacted support, but they keep giving me the runaround. The more I tried to fix it, the more problems came up. My bank account was notifiction, and then I got locked out of everything. The worst part is, I don’t even know who to trust anymore. Friends, family, everyone’s acting strange. It’s affecting my relationships and my mental health. Even my laptop isn’t working right anymore. It’s so stange how everything just fell apart after that one email.",
  "category": "Other Cyber Crime",
  "subcategory": "Malware attacks"
}

7. Input:
Regarding job vacancies they call me and ask the money for processing fees including this I share the details of the person whos contact me Amen verma Nithin Sachin
Output:


{
  "complain": "Regarding job vacancies they call me and ask the money for processing fees including this I share the details of the person whos contact me Amen verma Nithin Sachin",
  "category": "Financial Fraud Crimes",
  "subcategory": "Online Job Fraud"
}

8. Input:
Respected Cyber crime Ghatkopar east Mumbai This is Irshad Gafur Shaikh I reside in Ghatkopar east with my family and i am responsible citizen of India and my family I would like to highlight you about two fruadulant loan app which are quitely robbing to innocent and family responsible people like me Koko loan I was looking for k then filling my personal details it showed k then i clicked to check tenurity and roi It directly selected as applied itself and credited into my account of Rs and repayment amount is showing as k with days tenurity Screen shots shared for your reference AG Loan I was looking for k loan as per the app given limit for days tenurity and i applied for the same then next it credited rs into my bank account as showing repayment of k with days tenurity Screen shots and recording shared for your reference None of the above have mentioned contact center or points I tried to contact them also however its all scam I heartly request you to help me out from the same I am from middle class and i already having many family responaiblity I am ready for the same credited amount only but they are not acknowledging that
Output:


{
  "complain": "Respected Cyber crime Ghatkopar east Mumbai This is Irshad Gafur Shaikh I reside in Ghatkopar east with my family and i am responsible citizen of India and my family I would like to highlight you about two fruadulant loan app which are quitely robbing to innocent and family responsible people like me Koko loan I was looking for k then filling my personal details it showed k then i clicked to check tenurity and roi It directly selected as applied itself and credited into my account of Rs and repayment amount is showing as k with days tenurity Screen shots shared for your reference AG Loan I was looking for k loan as per the app given limit for days tenurity and i applied for the same then next it credited rs into my bank account as showing repayment of k with days tenurity Screen shots and recording shared for your reference None of the above have mentioned contact center or points I tried to contact them also however its all scam I heartly request you to help me out from the same I am from middle class and i already having many family responaiblity I am ready for the same credited amount only but they are not acknowledging that",
  "category": "Financial Fraud Crimes",
  "subcategory": "Loan Fraud"
}

9. Input:
Respected Sir A very serious matter I want to inform you Few person running or involve in some very shamefull activities by using few women at many places of kolkata gariahat ballygunge RUBY HOSPITAL BEHIND area KASBA ANANDAPUR QUEST MALL metropolis mall area ACROPOLISMALL area park circus FORUM MALL ELGIN RD Parkstreet MAIDAN AREA esplanade Garia jadavpur BEHALASAKHERBAZAR JOKA BANSDRONI Rabindrasadanexide area HARIDEVPUR triangular park lake mall area rashbehari area TOLLYGUNGE THAKURPUKUR BBD BAG DALHOUSIE AREA and SALTLAKE Their name SUBHRO SAHA AMLAN DATTA IZAZ AHMED Anirban They officially work in a insurance office hdfclife a hindustanpark ab gariahat shopping mall st floor beside of reliance trend building near gariahat more but outside at several places they involve in some shamefull activities last years Sir a person SUBHRO SAHA forcefully involve few women employee ex FEMALE employee in such shamefull doing At afternoon evening or after evening or night time they doing this shamefull activities Many innocent people are TRAPPED and suffering in such dirty issue for long time They are even to lodge a complain against them because of threatening and blackmailing ISSUE From above address PLACES and their mobile whatsapp no you can easily trace and track their all activities You need to investigate Last years detail Please help
Output:

{
  "complain": "Respected Sir A very serious matter I want to inform you Few person running or involve in some very shamefull activities by using few women at many places of kolkata gariahat ballygunge RUBY HOSPITAL BEHIND area KASBA ANANDAPUR QUEST MALL metropolis mall area ACROPOLISMALL area park circus FORUM MALL ELGIN RD Parkstreet MAIDAN AREA esplanade Garia jadavpur BEHALASAKHERBAZAR JOKA BANSDRONI Rabindrasadanexide area HARIDEVPUR triangular park lake mall area rashbehari area TOLLYGUNGE THAKURPUKUR BBD BAG DALHOUSIE AREA and SALTLAKE Their name SUBHRO SAHA AMLAN DATTA IZAZ AHMED Anirban They officially work in a insurance office hdfclife a hindustanpark ab gariahat shopping mall st floor beside of reliance trend building near gariahat more but outside at several places they involve in some shamefull activities last years Sir a person SUBHRO SAHA forcefully involve few women employee ex FEMALE employee in such shamefull doing At afternoon evening or after evening or night time they doing this shamefull activities Many innocent people are TRAPPED and suffering in such dirty issue for long time They are even to lodge a complain against them because of threatening and blackmailing ISSUE From above address PLACES and their mobile whatsapp no you can easily trace and track their all activities You need to investigate Last years detail Please help",
  "category": "Women/Child Related Crime",
  "subcategory": "Sale, Publishing and Transmitting Obscene Material/Sexually Explicit Material"
}

Example 10:
Input:
Hello please help me and more like me who are suffering financial frauds from these kinds of applications. I only downloaded the app, and without my consent, they gave me a loan and credited the amount into my account. They are asking for payment even after I’ve paid, and there’s no update in the application. They’ve accessed my contacts and are threatening to call them. I’m frustrated and need help.
Output:


{
  "complain": "Hello please help me and more like me who are suffering financial frauds from these kinds of applications. I only downloaded the app, and without my consent, they gave me a loan and credited the amount into my account. They are asking for payment even after I’ve paid, and there’s no update in the application. They’ve accessed my contacts and are threatening to call them. I’m frustrated and need help.",
  "category": "unable to identify",
  "subcategory": "unable to identify"
}

Example 11:
Input:

I had continue received random calls and abusive messages in my whatsapp Someone added my number in a unknown facebook group name with Only Girls and still getting calls from unknown numbers pls help me and sort out the issue as soon as possible Thank you
Output:


{
  "complain": "I had continue received random calls and abusive messages in my whatsapp Someone added my number in a unknown facebook group name with Only Girls and still getting calls from unknown numbers pls help me and sort out the issue as soon as possible Thank you",
  "category": "Other Cyber Crime",
  "subcategory": "Cyber Bullying/Stalking/Sexting"
}

Example 12:
Input:

The above fraudster is continuously messaging me and Asking me to pay him money or he will send fake cropped nude photos of me to my other contacts through WhatsApp. I am unaware how he has received my contacts list from my phone. Please help.
Output:
{
  "complain": "The above fraudster is continuously messaging me and Asking me to pay him money or he will send fake cropped nude photos of me to my other contacts through WhatsApp. I am unaware how he has received my contacts list from my phone. Please help.",
  "category": "Other Cyber Crime",
  "subcategory": "Cyber Bullying/Stalking/Sexting"
}

Example 13:
Input:
In apna Job I have applied for job interview for telecalling and the resource management wrote that twelve hundred will be charged for security amount of laptop and work from home when I have given interview on the given address next day they charged twelve hundred and six hundred more money in the name of insurance after that they have referred me to the job calling there is no work of laptop neither a work from home kindly please take action against it as soon as possible and if possible please help me to recover my financial loss
Output:

{
  "complain": "In apna Job I have applied for job interview for telecalling and the resource management wrote that twelve hundred will be charged for security amount of laptop and work from home when I have given interview on the given address next day they charged twelve hundred and six hundred more money in the name of insurance after that they have referred me to the job calling there is no work of laptop neither a work from home kindly please take action against it as soon as possible and if possible please help me to recover my financial loss",
  "category": "Financial Fraud Crimes",
  "subcategory": "Online Job Fraud"
}

Example 14:
Input:

I received a call from lady stating that she will send new phone of vivo and I received that parcel through post on th February to Kurnool head post office where I have not received any mobile
Output:
{
  "complain": "I received a call from lady stating that she will send new phone of vivo and I received that parcel through post on th February to Kurnool head post office where I have not received any mobile",
  "category": "unable to identify",
  "subcategory": "unable to identify"
}

Example 15:
Input:
FRAUD UPI PAYTM BANK Punjab National Bank including Oriental Bank of Commerce and United Bank of India ACCOUNT NUMBER TOTAL AMOUNT PLEASE HOLD REVERSE TOTAL AMOUNT IN THE COMPLAINT ACCOUNT AND TAKE NECESSARY ACTION
Output:
{
  "complain": "FRAUD UPI PAYTM BANK Punjab National Bank including Oriental Bank of Commerce and United Bank of India ACCOUNT NUMBER TOTAL AMOUNT PLEASE HOLD REVERSE TOTAL AMOUNT IN THE COMPLAINT ACCOUNT AND TAKE NECESSARY ACTION",
  "category": "unable to identify",
  "subcategory": "unable to identify"
}

Example 16:
Input:
I got the message on Whatsapp to my number The message contains very abusive words This message also includes my friend name and his number in that The same message was forwarded to all other friends also For more details please look into the file attached here Please take action ASAP
Output:

{
  "complain": "I got the message on Whatsapp to my number The message contains very abusive words This message also includes my friend name and his number in that The same message was forwarded to all other friends also For more details please look into the file attached here Please take action ASAP",
  "category": "Other Cyber Crime",
  "subcategory": "Cyber Bullying/Stalking/Sexting"
}

Example 17:
Input:
Details entered in pdf file Person posing as Army officer msg us that he want our place on rent and for that to confirm the account he wants us to transfer money in his account and once confirmed he will transfer back
Output:

{
  "complain": "Details entered in pdf file Person posing as Army officer msg us that he want our place on rent and for that to confirm the account he wants us to transfer money in his account and once confirmed he will transfer back",
  "category": "Financial Fraud Crimes",
  "subcategory": "Online Matrimonial Fraud"
}
Example 18:
Input:
I received a Whatsapp number in Happn Dating app Then I texted in Whatsapp after that they did a video call asked me to show the face I did then asked me to remove my clothes I did After that they recorded those videos and asking for me to send money I sent again they are asking me Kindly help me in this situation Also if needed i can come in person to meet and give more details Please Help
Output:

{
  "complain": "I received a Whatsapp number in Happn Dating app Then I texted in Whatsapp after that they did a video call asked me to show the face I did then asked me to remove my clothes I did After that they recorded those videos and asking for me to send money I sent again they are asking me Kindly help me in this situation Also if needed i can come in person to meet and give more details Please Help",
  "category": "Other Cyber Crime",
  "subcategory": "Cyber Bullying/Stalking/Sexting"
}

Example 19:
Input:
Someone changed my email id nd contact number by using anydesk app nd now he had ordered product from my account through emi my contact number is nd he changed to this number nd email id also have been changed now he have access to my account
Output:

{
  "complain": "Someone changed my email id nd contact number by using anydesk app nd now he had ordered product from my account through emi my contact number is nd he changed to this number nd email id also have been changed now he have access to my account",
  "category": "Other Cyber Crime",
  "subcategory": "Profile Hacking/Identity Theft"
}
Example 20:
Input:
I have a friend with whom I made deal to exchange my gaming account of BGMI and he found an account as well for exchange So I shared my login details with him to check the inventory available in my account Suddenly I received a mail that my email id has been changed When I tried contacting him he blocked my call and when I tried calling on WhatsApp he is not answering the call I have spent more than Rs in my gaming account Request you to please regain my account
Output:
{
  "complain": "I have a friend with whom I made deal to exchange my gaming account of BGMI and he found an account as well for exchange So I shared my login details with him to check the inventory available in my account Suddenly I received a mail that my email id has been changed When I tried contacting him he blocked my call and when I tried calling on WhatsApp he is not answering the call I have spent more than Rs in my gaming account Request you to please regain my account",
  "category": "Other Cyber Crime",
  "subcategory": "Profile Hacking/Identity Theft"
}
Example 21:
Input:

vbnet
Copy code
FRAUD THROUGH DebitCredit Card FraudSim Swap Fraud BANK Airtel Payments Bank ACCOUNT NO TOTAL AMOUNT PLEASE HOLD REVERSE TOTAL AMOUNT IN THE COMPLAINT ACCOUNT AND TAKE NECESSARY ACTION
Output:

{
  "complain": "FRAUD THROUGH DebitCredit Card FraudSim Swap Fraud BANK Airtel Payments Bank ACCOUNT NO TOTAL AMOUNT PLEASE HOLD REVERSE TOTAL AMOUNT IN THE COMPLAINT ACCOUNT AND TAKE NECESSARY ACTION",
  "category": "Financial Fraud Crimes",
  "subcategory": "Debit/Credit Card Fraud"
}

Example 22:
Input:

Received Call from unknown person claimed to be related to his father and said that he had borrowed rs from his father and want to refund first he confirmed account by sending rs their after he has theft rs by transaction of rs each call received from mobile no
Output:

{
  "complain": "Received Call from unknown person claimed to be related to his father and said that he had borrowed rs from his father and want to refund first he confirmed account by sending rs their after he has theft rs by transaction of rs each call received from mobile no",
  "category": "Financial Fraud Crimes",
  "subcategory": "Internet Banking-Related Fraud"
}

Example 22:
Input:
FRAUD THROUGH UPI Phone Pe BANK BARODA UP GRAMIN BANK ACCOUNT NUMBER TOTAL AMOUNT PLEASE HOLD REVERSE TOTAL AMOUNT IN THE COMPLAINT ACCOUNT AND TAKE NECESSARY ACTION
Output:

{
  "complain": "FRAUD THROUGH UPI Phone Pe BANK BARODA UP GRAMIN BANK ACCOUNT NUMBER TOTAL AMOUNT PLEASE HOLD REVERSE TOTAL AMOUNT IN THE COMPLAINT ACCOUNT AND TAKE NECESSARY ACTION",
  "category": "unable to identify",
  "subcategory": "unable to identify"
}

Example 23:
Input:

I wanted to sell my cot on Quikr This person named Ankit Sharma Shop was Interested I am new to Googlepay Voucher payment and he sent me a voucher to pay the amount to my account but the transaction was reverse and he got paid the amount
Output:

{
  "complain": "I wanted to sell my cot on Quikr This person named Ankit Sharma Shop was Interested I am new to Googlepay Voucher payment and he sent me a voucher to pay the amount to my account but the transaction was reverse and he got paid the amount",
  "category": "Financial Fraud Crimes",
  "subcategory": "Internet Banking-Related Fraud"
}

Example 24:
Input:
R sir someone call me from and said that he is my known JAGDISH and he said some money on my mobile googlepay after that he said a link on my googlepay on rupees then i click on this link the money is deducted from my account so please solve the same asap
Output:


{
  "complain": "R sir someone call me from and said that he is my known JAGDISH and he said some money on my mobile googlepay after that he said a link on my googlepay on rupees then i click on this link the money is deducted from my account so please solve the same asap",
  "category": "Financial Fraud Crimes",
  "subcategory": "Internet Banking-Related Fraud"
}

25. Input:
Online job fraud victim received a link related to online job goes to payment page for processing fee otp entered amount lost cheated Suspect no httpsquikrjobssite
Output:

{
  "complain": "Online job fraud victim received a link related to online job goes to payment page for processing fee otp entered amount lost cheated Suspect no httpsquikrjobssite",
  "category": "Financial Fraud Crimes",
  "subcategory": "Online Job Fraud"
}

26. Input:
Stop that like fruod for any body do not sher your otp and other ccvcard numberwith other do not resive new number callcastomer family member ferinds with any person do not sher otip and cvv number do not follow any instructions for calls massages linkes or other related questions inform the public about no cheating
Output:


{
  "complain": "Stop that like fruod for any body do not sher your otp and other ccvcard numberwith other do not resive new number callcastomer family member ferinds with any person do not sher otip and cvv number do not follow any instructions for calls massages linkes or other related questions inform the public about no cheating",
  "category": "Financial Fraud Crimes",
  "subcategory": "Online Job Fraud"
}

26. Input:
RUPAY KA RECHAREGE PHONE PE SE KARNE KE UPRANT THODI DER BAD ACCOUNT SE PASE KAT CHUKE THE MESSAGE DWARA PATA CHALA KAT GYE THE SE FEB BANK BAND HONE SE KO SUCHIT NAHI KARA PYE FEB KO BANK KO APPLICATION DWARA SUCHIT KIYA TO YE PASE KAT KARKE GALTI SE NIKALE GAYE HAI KRIPYA ISKI SAHI JACH KAR ACCOUNT ME PASE LAUTANE KI KRIPA KARE
Output:

{
  "complain": "RUPAY KA RECHAREGE PHONE PE SE KARNE KE UPRANT THODI DER BAD ACCOUNT SE PASE KAT CHUKE THE MESSAGE DWARA PATA CHALA KAT GYE THE SE FEB BANK BAND HONE SE KO SUCHIT NAHI KARA PYE FEB KO BANK KO APPLICATION DWARA SUCHIT KIYA TO YE PASE KAT KARKE GALTI SE NIKALE GAYE HAI KRIPYA ISKI SAHI JACH KAR ACCOUNT ME PASE LAUTANE KI KRIPA KARE",
  "category": "Financial Fraud Crimes",
  "subcategory": "Online Job Fraud"
}

27. Input:
Hello please help me and more like me who are suffering financial frauds from these kind of applications I only downloaded the app without my consent they gave me loan of and credited amount in my account for only days they are asking for payment of and even now i had done my payment still no update is done in application still showing for payment and the customer who was earlier taalking to me on whatsapp now has switched off her phone and they have accessed all my contacts and are threatning me to call them I am too much frustated please help this is the last hope from you all and i tried everywhere but i didnt get any response from any source since the payment is not showing in qpplicatun they will ask for bounce charge and threaten me to callplease look into the matter not only me is trapped in this there could be number of poor persons like me So at last please help
Output:

{
  "complain": "Hello please help me and more like me who are suffering financial frauds from these kind of applications I only downloaded the app without my consent they gave me loan of and credited amount in my account for only days they are asking for payment of and even now i had done my payment still no update is done in application still showing for payment and the customer who was earlier taalking to me on whatsapp now has switched off her phone and they have accessed all my contacts and are threatning me to call them I am too much frustated please help this is the last hope from you all and i tried everywhere but i didnt get any response from any source since the payment is not showing in qpplicatun they will ask for bounce charge and threaten me to callplease look into the matter not only me is trapped in this there could be number of poor persons like me So at last please help",
  "category": "Financial Fraud Crimes",
  "subcategory": "Online Job Fraud"
}

28. Input:
Sir I have invested around lakh in these app from they are very smart and initially keep their payment system clean with no doubt and from they creating problem in payments Please help
Output:
{
  "complain": "Sir I have invested around lakh in these app from they are very smart and initially keep their payment system clean with no doubt and from they creating problem in payments Please help",
  "category": "Financial Fraud Crimes",
  "subcategory": "Online Job Fraud"
}

29. Input:
This is an unauthorized transaction from an international website Vimeocom I did not receive any prior intimation or authorization mail or notification for the transaction I have blocked the card and raised a complaint with the bank authorities as well Please help
Output:

{
  "complain": "This is an unauthorized transaction from an international website Vimeocom I did not receive any prior intimation or authorization mail or notification for the transaction I have blocked the card and raised a complaint with the bank authorities as well Please help",
  "category": "Financial Fraud Crimes",
  "subcategory": "Debit/Credit Card Fraud"
}

30. Input:
A call from this number was received by me saying that speaking from indusind bank helping me to make credit card I received a call at pm first a lady was speaking then the call was transferred by them to another person the were having a fake url website made by them only They make me to open the site and told me to fill the details i did so they said that a rupees otp will come to me as a charges of card they said a virtual card will be generated of rupees but the virtual card was not generated they asked me to fill the card number again then the amount was deducted from my card of approximately
Output:

{
  "complain": "A call from this number was received by me saying that speaking from indusind bank helping me to make credit card I received a call at pm first a lady was speaking then the call was transferred by them to another person the were having a fake url website made by them only They make me to open the site and told me to fill the details i did so they said that a rupees otp will come to me as a charges of card they said a virtual card will be generated of rupees but the virtual card was not generated they asked me to fill the card number again then the amount was deducted from my card of approximately",
  "category": "Financial Fraud Crimes",
  "subcategory": "Debit/Credit Card Fraud"
}

31. Input:
we received call from salomi saying she is custom officer in mumbai one more person is also invoved joshil patel from usa he was also involved in this they both have created scam for me and looted from me as an custom duty joshil patel introduced me as my old friend from school he said i will send you some small gift as a friendship we thought its the same parcel but the are now creating story and nobody is giving us details of the parcel its a complete fraud please helo us
Output:

{
  "complain": "we received call from salomi saying she is custom officer in mumbai one more person is also invoved joshil patel from usa he was also involved in this they both have created scam for me and looted from me as an custom duty joshil patel introduced me as my old friend from school he said i will send you some small gift as a friendship we thought its the same parcel but the are now creating story and nobody is giving us details of the parcel its a complete fraud please helo us",
  "category": "Financial Fraud Crimes",
  "subcategory": "Online Job Fraud"
}

32. Input:
FRAUD THROUGH UPI PHONE PE BANK STATE BANK OF INDIA ACCOUNT NUMBER TOTAL AMOUNT PLEASE HOLD REVERSE TOTAL AMOUNT IN THE COMPLAINT ACCOUNT AND TAKE NECESSARY ACTION
Output:

{
  "complain": "FRAUD THROUGH UPI PHONE PE BANK STATE BANK OF INDIA ACCOUNT NUMBER TOTAL AMOUNT PLEASE HOLD REVERSE TOTAL AMOUNT IN THE COMPLAINT ACCOUNT AND TAKE NECESSARY ACTION",
  "category": "Financial Fraud Crimes",
  "subcategory": "Online Job Fraud"
}

34. Input:
Citizen Details Address Name BHAGCHAND SAINI MOBILE NO DIST DAUSA PS SIKANDRA EMAIL ID bhagchandmaligmailcom PINCODE BANK STATE BANK OF INDIA AC NO BRANCH BHANDARANGE Citizen Ke sath Total Fraud Amount Rs DATE Jan Fraud By Phone Pay No Transction id T UTR Amount Rs TIME PM Frauder Detals Suchna karta ne bataya ki unke pass unhone no se call aaya or jankar bankar ki baat ki or paise transfer karva liye
Output:

{
  "complain": "Citizen Details Address Name BHAGCHAND SAINI MOBILE NO DIST DAUSA PS SIKANDRA EMAIL ID bhagchandmaligmailcom PINCODE BANK STATE BANK OF INDIA AC NO BRANCH BHANDARANGE Citizen Ke sath Total Fraud Amount Rs DATE Jan Fraud By Phone Pay No Transction id T UTR Amount Rs TIME PM Frauder Detals Suchna karta ne bataya ki unke pass unhone no se call aaya or jankar bankar ki baat ki or paise transfer karva liye",
  "category": "Financial Fraud Crimes",
  "subcategory": "Internet Banking-Related Fraud"
}

35. Input:
FRAUD THROUGH UPI PHONE PE BANK UCO BANK ACCOUNT NUMBER TOTAL AMOUNT PLEASE HOLD REVERSE TOTAL AMOUNT IN THE COMPLAINT ACCOUNT AND TAKE NECESSARY ACTION
Output:

{
  "complain": "FRAUD THROUGH UPI PHONE PE BANK UCO BANK ACCOUNT NUMBER TOTAL AMOUNT PLEASE HOLD REVERSE TOTAL AMOUNT IN THE COMPLAINT ACCOUNT AND TAKE NECESSARY ACTION",
  "category": "Financial Fraud Crimes",
  "subcategory": "Online Job Fraud"
}

35. Input:
FRAUD THROUGH UPI FRAUD GOOGLE PAY BANK BANK OF BARODA ACCOUNT NUMBER TOTAL AMOUNT PLEASE HOLD REVERSE TOTAL AMOUNT IN THE COMPLAINT ACCOUNT AND TAKE NECESSARY ACTION
Output:

{
  "complain": "FRAUD THROUGH UPI FRAUD GOOGLE PAY BANK BANK OF BARODA ACCOUNT NUMBER TOTAL AMOUNT PLEASE HOLD REVERSE TOTAL AMOUNT IN THE COMPLAINT ACCOUNT AND TAKE NECESSARY ACTION",
  "category": "Financial Fraud Crimes",
  "subcategory": "Online Job Fraud"
}

36. Input:
Online Frauds Gaming Fraud Any Other victim paid some amount for free fire game access id so later he came to know that it was a fraud
Output:

{
  "complain": "Online Frauds Gaming Fraud Any Other victim paid some amount for free fire game access id so later he came to know that it was a fraud",
  "category": "Financial Fraud Crimes",
  "subcategory": "Online Job Fraud"
}

37. Input:
httpswwwxnxxtvvideousapbfuckkkarrr Above link is correct video URl she is one of our relative Please help her now she is going to get marry other person they are not aware of this information while its recording some malwere functionality has recorded without their permission Please help her and remove the above video
Output:

{
  "complain": "httpswwwxnxxtvvideousapbfuckkkarrr Above link is correct video URl she is one of our relative Please help her now she is going to get marry other person they are not aware of this information while its recording some malwere functionality has recorded without their permission Please help her and remove the above video",
  "category": "Financial Fraud Crimes",
  "subcategory": "Online Job Fraud"
}

38. Input:
His name is Avaneesh Parasar staying in Patna at FLAT RANJAN PALACE MAGISTRATE COLONY ASHIYANA DIGHA ROAD POST AASHIYANA NAGAR THANA RAJIV NAGAR DIS PATNA PIN CODE He took crores of rupees
Output:

{
  "complain": "His name is Avaneesh Parasar staying in Patna at FLAT RANJAN PALACE MAGISTRATE COLONY ASHIYANA DIGHA ROAD POST AASHIYANA NAGAR THANA RAJIV NAGAR DIS PATNA PIN CODE He took crores of rupees",
  "category": "Financial Fraud Crimes",
  "subcategory": "Online Job Fraud"
}
---

### *Important Notes*:
- *Follow the exact classification template.* The output must *match* the format of complain:, category:, and subcategory:.
- *Do not classify complaints* outside the *above-mentioned categories*. Only use the provided categories and subcategories.
- If a complaint doesn't fit a specific subcategory perfectly, pick the *most relevant* one from the list. Be precise in your analysis.
- If you *cannot identify the category or subcategory* for a complaint, output:

### *End of Prompt*"""

# %%
import pandas as pd
import numpy as np
dataset = pd.read_csv("mnt/data/content/Training_Complaints - Sheet.csv")

# %%
dataset['output'] = " "
dataset.head()

# %%
print(dataset['Compliant'].count())
# Out:
# 14838

# %%
dataset = dataset.drop(columns=['Unnamed: 1'])
dataset.head()
# Out:
#                                            Compliant output
# 0  I had continue received random calls and abusi...
# 1  The above fraudster is continuously messaging ...
# 2  He is acting like a police and demanding for m...
# 3  In apna Job I have applied for job interview f...
# 4  I received a call from lady stating that she w...

# %%
# strng = ""  # Initialize an empty string
# # Iterate through rows in the DataFrame
# for index, row in dataset.iterrows():  # Change df to dataset
#     prepare_data.append(f"input: {str(row['Compliant'])}")  # Convert 'Compliant' to string
#     prepare_data.append(f'output: {"" if row["output"] is None else str(row["output"])}')  # Handle None as empty
#     # strng += f"\"input: {str(row['Compliant'])}\",\n\"output: {"" if row['output'] is None else str(row['output'])}\",\n\n"
# # Display the final string
# print(prepare_data)
# total_length = len(prepare_data)
# chunk_size = 150
# chunks = [prepare_data[i:i + chunk_size] for i in range(0, len(prepare_data), chunk_size)]

# %%
import numpy as np
import os
import google.generativeai as genai
import pandas as pd
import time
from datetime import timedelta as td, datetime as dt

# Configure the model API key
genai.configure(api_key="AIzaSyD7b-zJYHIngzgCS7UTe2NyOdpJ-yiX1mY")

# Create the model configuration
generation_config = {
    "temperature": 1,
    "top_p": 0.95,
    "top_k": 40,
    "max_output_tokens": 8192,
    "response_mime_type": "text/plain",
}

# Initialize the model
model = genai.GenerativeModel(
    model_name="gemini-1.5-flash",
    generation_config=generation_config,
)

# Define a function to process and chunk data
def preprocess_data(dataset, chunk_size=20):
    """Prepare the data by chunking into smaller batches."""
    print(f"Starting to preprocess and chunk data into size {chunk_size}...")
    prepared_data = []  # List to hold formatted complaints
    for index, row in dataset.iterrows():
        prepared_data.append(f"input: {str(row['Compliant'])}")
        prepared_data.append(f"output: {'' if row['output'] is None else str(row['output'])}")

    # Split data into chunks of size chunk_size
    chunks = [prepared_data[i:i + chunk_size] for i in range(0, len(prepared_data), chunk_size)]
    print(f"Data preprocessing complete. {len(chunks)} chunks prepared.")
    return chunks

# Define a function to send data to the model and process it
def generate_and_process_chunk(chunk_data, prompt):
    """Send chunk data to LLM and get processed output."""
    print("\nProcessing chunk...")
    try:
        # Concatenate the prompt string with the chunked data
        full_input = prompt + "\n".join(chunk_data)

        # # Print the input data (for tracking)
        # print(f"\nInput text sent to the model:\n{full_input}\n")

        # Generate content using the model
        print("Sending data to the LLM for processing...")
        response = model.generate_content(full_input)

        if not response.candidates:
            print("Blocked prompt detected. Skipping this batch.\n")
            return []

        print("Response received from the LLM.\n")

        # Print the generated response for tracking
        print(f"Generated text from LLM:\n{response.text}\n")

        return {
            "Generated_Response": [response.text]
        }

    except Exception as e:
        print(f"Error during content generation for chunk: {str(e)}\n")
        return []

# Define a function to generate content in batches and save the results to CSV
def generate_and_save_csv(dataset, prompt, output_csv="Generate_report_1.csv"):
    print(f"\nStarting content generation and saving to {output_csv}...\n")
    chunks = preprocess_data(dataset, chunk_size=20)  # Preprocess and chunk data

    for idx, chunk in enumerate(chunks, 1):
        print(f"\nProcessing chunk {idx} of {len(chunks)}...\n")
        # Generate and process the chunk of data
        result = generate_and_process_chunk(chunk, prompt)

        if result:
            # Convert the result to a DataFrame and save it to a CSV file
            print(f"\nSaving results for chunk {idx} to CSV...\n")
            res_dataset = pd.DataFrame(result)
            res_dataset.to_csv(output_csv, mode='a', index=False, header=not os.path.exists(output_csv))
            print(f"Processed chunk {idx} and saved to {output_csv}\n")
        else:
            print(f"Skipping chunk {idx} due to empty result or blocked response.\n")


# Generate and save the content to CSV
generate_and_save_csv(dataset, prompt)
# Out:
# Streaming output truncated to the last 5000 lines.
#  time pm amount   traT utr no
# category: Financial Fraud Crimes
# subcategory: UPI-Related Frauds
#
# complain: Respected Sir
#
# A very serious matter I want to inform you Few person running or involve in some very shamefull activities by using few women at many places of kolkata gariahat ballygunge RUBY HOSPITAL BEHIND area KASBA ANANDAPUR QUEST MALL metropolis mall area ACROPOLISMALL area park circus FORUM MALL ELGIN RD Parkstreet MAIDAN AREA esplanade Garia jadavpur BEHALASAKHERBAZAR JOKA BANSDRONI  Rabindrasadanexide area  HARIDEVPUR triangular park lake mall area rashbehari area TOLLYGUNGE THAKURPUKUR BBD BAG DALHOUSIE AREA  and SALTLAKE
#
# Their name
# SUBHRO SAHA AMLAN DATTA
# IZAZ AHMED Anirban
#
#
# ...

# %%
import numpy as np
import os
import google.generativeai as genai
import pandas as pd
import time
import re
from datetime import timedelta as td, datetime as dt

# Configure the model API key
genai.configure(api_key="AIzaSyD7b-zJYHIngzgCS7UTe2NyOdpJ-yiX1mY")

# Create the model configuration
generation_config = {
    "temperature": 1,
    "top_p": 0.95,
    "top_k": 40,
    "max_output_tokens": 8192,
    "response_mime_type": "text/plain",
}

# Initialize the model
model = genai.GenerativeModel(
    model_name="gemini-1.5-flash",
    generation_config=generation_config,
)

# Define a function to process and chunk data
def preprocess_data(dataset, chunk_size=10):
    """Prepare the data by chunking into smaller batches."""
    print(f"Starting to preprocess and chunk data into size {chunk_size}...")
    prepared_data = []  # List to hold formatted complaints
    for index, row in dataset.iterrows():
        prepared_data.append(f"input: {str(row['Compliant'])}")
        prepared_data.append(f"output: {'' if row['output'] is None else str(row['output'])}")

    # Split data into chunks of size chunk_size
    chunks = [prepared_data[i:i + chunk_size] for i in range(0, len(prepared_data), chunk_size)]
    print(f"Data preprocessing complete. {len(chunks)} chunks prepared.")
    return chunks

# Define a function to send data to the model and process it
def generate_and_process_chunk(chunk_data):
    """Send chunk data to LLM and get processed output."""
    print(f"Processing chunk with {len(chunk_data)} entries...")
    try:
        # Generate content using the model
        print("Sending data to the LLM for processing...")
        response = model.generate_content("\n".join(chunk_data))

        if not response.candidates:
            print("Blocked prompt detected. Skipping this batch.")
            return []

        print("Response received from the LLM.")
        conv_to_json = response.text
        json_objects = re.findall(r'\{[^}]*\}', conv_to_json)

        inputs, outputs, subcategories = [], [], []

        # Extract relevant data from the generated JSON
        for item in json_objects:
            # Extract user complaint
            input_match = re.search(r'"complaint": "(.*?)"', item, re.IGNORECASE)
            user_complaint = input_match.group(1) if input_match else ""
            inputs.append(user_complaint)

            # Extract category/error
            output_match = re.search(r'(?:"error":| "Category Name":)\s*"(.*?)"', item, re.IGNORECASE)
            error_or_category = output_match.group(1) if output_match else ""
            outputs.append(error_or_category)

            # Extract subcategory
            subcategory_match = re.search(r'"Subcategory Name":\s*"(.*?)"', item, re.IGNORECASE)
            subcategory_name = subcategory_match.group(1) if subcategory_match else "error unable to identify"
            subcategories.append(subcategory_name)

        print(f"Chunk processed successfully. {len(inputs)} entries extracted.")
        return {
            "Complain": inputs,
            "Category": outputs,
            "Subcategory Name": subcategories
        }

    except Exception as e:
        print(f"Error during content generation for chunk: {str(e)}")
        return []

# Define a function to generate content in batches and save the results to CSV
def generate_and_save_csv(dataset, output_csv="Generate_report_1.csv"):
    print(f"Starting content generation and saving to {output_csv}...")
    chunks = preprocess_data(dataset, chunk_size=10)  # Preprocess and chunk data

    for idx, chunk in enumerate(chunks, 1):
        print(f"Processing chunk {idx} of {len(chunks)}...")
        # Generate and process the chunk of data
        result = generate_and_process_chunk(chunk)

        if result:
            # Convert the result to a DataFrame and save it to a CSV file
            print(f"Saving results for chunk {idx} to CSV...")
            res_dataset = pd.DataFrame(result)
            res_dataset.to_csv(output_csv, mode='a', index=False, header=not os.path.exists(output_csv))
            print(f"Processed chunk {idx} and saved to {output_csv}")
        else:
            print(f"Skipping chunk {idx} due to empty result or blocked response.")

# Sample DataFrame (replace with your actual dataset)
# Sample DataFrame for testing, replace this with actual data

# Generate and save the content to CSV
generate_and_save_csv(dataset)

# %%
#-------------------------------------------------

# Function to generate content and save as CSV
def generate_and_save_csv(arg_data):
    try:

        response = model.generate_content(arg_data)  # Pass content to generate content
        if not response.candidates:
            print("Blocked prompt detected. Reason:", response.prompt_feedback.block_reason)
            return  # Skip processing this chunk

        conv_to_json = response.text
        json_objects = re.findall(r'\{[^}]*\}', conv_to_json)
        inputs = []
        outputs = []
        subcategories = []
        for item in json_objects:
            # Extract 'user complaint'
            input_match = re.search(r'"user complaint": "(.*?)"', item, re.IGNORECASE)
            user_complaint = input_match.group(1) if input_match else ""
            inputs.append(user_complaint)

            # Extract 'error' or 'Category Name'
            output_match = re.search(r'(?:"error":| "Category Name":)\s*"(.*?)"', item, re.IGNORECASE)
            error_or_category = output_match.group(1) if output_match else ""
            outputs.append(error_or_category)

            # Extract 'Subcategory Name'
            subcategory_match = re.search(r'"Subcategory Name":\s*"(.*?)"', item, re.IGNORECASE)
            subcategory_name = subcategory_match.group(1) if subcategory_match else "error unable to identify"
            subcategories.append(subcategory_name)
        data1 = {
            "Complain": inputs,  # List of user complaints
            "Category": outputs,  # Corresponding categories or errors
            "Subcategory Name": subcategories
        }
        # Create a DataFrame from the dictionary
        res_dataset = pd.DataFrame(data1)
        data1.clear
        # Save the DataFrame to a CSV file
        csv_file_path = "Generate_report_1.csv"
        res_dataset.to_csv(csv_file_path,mode='a', index=False,header=False)
        print(f"CSV file has been saved as {csv_file_path}")
        print("Response processed successfully.")
    except Exception as e:
        print("Error during content generation:", str(e))

#-----------------------------------
# chunk_size = 100
# total_length = len(prepare_data)

# # Create the chunks
# chunks = [prepare_data[i:i + chunk_size] for i in range(0, total_length, chunk_size)]

# # If the last chunk is smaller than 2998, merge it with the previous chunk
# if len(chunks[-1]) < chunk_size:
#     chunks[-2].extend(chunks[-1])  # Merge last chunk into the second last chunk
#     chunks = chunks[:-1]  # Remove the now empty last chunk

# # Now, `chunks` will contain only chunks of exactly 2998 elements

# Check if each chunk has exactly 1000 elements
j=1
start_time = dt.now()
len_of_chunk=0
for i, chunk in enumerate(chunks):
  # end_time = dt.now()
  # timediff= end_time - start_time
  # if timediff <= td(seconds=58) and j > 15:
  #   time.sleep(abs(timediff.seconds - 61))
  #   print(f"Chunk {i+1} ({len(chunk)} elements):")
  #   # Step 1: Generate the first CSV file
  #   start_time = dt.now()
  #   generate_and_save_csv(data+chunk)
  #   print(chunk)
  #   print("-" * 50)
  #   print("Start Time:", start_time)
  #   j=1
  # else:
  #   print(f"Chunk {i+1} ({len(chunk)} elements):")
  #   # Step 1: Generate the first CSV file
  #   generate_and_save_csv(data+chunk[:2])
  #   print(chunk)
  #   print("-" * 50)
  #   j=j+1
  if j>3:
    break
  else:
    # generate_and_save_csv(data+chunk)
    len_of_chunk = len_of_chunk+len(chunk)
    j=j+1
print(len_of_chunk/2)
    # print(data+chunk[:2])
# print("Inputs:", inputs)
# print("Outputs:", outputs)
# print("Subcategories:", subcategories)

# # Ensure lists are of the same length
# if len(inputs) == len(outputs) == len(subcategories):
#     # Create a dictionary with the data
#     data = {
#         "Complain": inputs,  # List of user complaints
#         "Category": outputs,  # Corresponding categories or errors
#         "Subcategory Name": subcategories
#     }

#     # Create a DataFrame from the dictionary
#     dataset = pd.DataFrame(data)

#     # Save the DataFrame to a CSV file
#     # csv_file_path = "Generate_report_1.csv"
#     # dataset.to_csv(csv_file_path, index=False)
# #     print(f"CSV file has been saved as {csv_file_path}")
# # else:
# #     print("Error: Mismatch in data lengths. Cannot create DataFrame.")
# Out:
# 225.0

# %%
import datetime, time
start_time = datetime.datetime.now()
print("Start Time:", start_time)
time.sleep(30)
end_time = datetime.datetime.now()
print("End Time:", end_time)
timediff= end_time - start_time

if(timediff <= datetime.timedelta(minutes=1)):
  time.sleep(abs(timediff.seconds - 61));
  print("holding time:", (timediff.seconds-60))
# Out:
# Start Time: 2024-12-08 08:08:45.196602
# End Time: 2024-12-08 08:09:15.228539
# holding time: -30

# %%
import numpy as np
import os
import google.generativeai as genai
import pandas as pd
import time
import re

# Configure the generative AI model
genai.configure(api_key="AIzaSyD7b-zJYHIngzgCS7UTe2NyOdpJ-yiX1mY")

# Create the model configuration
generation_config = {
    "temperature": 1,
    "top_p": 0.95,
    "top_k": 40,
    "max_output_tokens": 8192,
    "response_mime_type": "text/plain",
}

model = genai.GenerativeModel(
    model_name="gemini-1.5-flash",
    generation_config=generation_config,
)

# Initialize lists for inputs, outputs, and subcategories
inputs = []
outputs = []
subcategories = []

# Function to generate content and save as CSV
def generate_and_save_csv(arg_data):
    try:
        response = model.generate_content(arg_data)  # Pass content to generate content

        # If no valid response or no candidates, skip this chunk
        if not response.candidates:
            print("Blocked prompt detected. Reason:", response.prompt_feedback.block_reason if hasattr(response, 'prompt_feedback') else 'Unknown')
            return None  # Return None if response is invalid

        conv_to_json = response.text
        json_objects = re.findall(r'\{[^}]*\}', conv_to_json)

        # Process each JSON object
        for data in json_objects:
            # Extract 'user complaint'
            input_match = re.search(r'"user complaint": "(.*?)"', data, re.IGNORECASE)
            user_complaint = input_match.group(1) if input_match else ""
            inputs.append(user_complaint)

            # Extract 'error' or 'Category Name'
            output_match = re.search(r'(?:"error":| "Category Name":)\s*"(.*?)"', data, re.IGNORECASE)
            error_or_category = output_match.group(1) if output_match else ""
            outputs.append(error_or_category)

            # Extract 'Subcategory Name'
            subcategory_match = re.search(r'"Subcategory Name":\s*"(.*?)"', data, re.IGNORECASE)
            subcategory_name = subcategory_match.group(1) if subcategory_match else "error unable to identify"
            subcategories.append(subcategory_name)

        print("Response processed successfully.")

        print("Dataset shape:", len(dataset) if 'dataset' in locals() else "No dataset created.")

    except Exception as e:
        print("Error during content generation:", str(e))

# Prepare chunks for processing
chunk_size = 100
 # Assuming you have your data ready to process

total_length = len(prepare_data)

# Create the chunks
chunks = [prepare_data[i:i + chunk_size] for i in range(0, total_length, chunk_size)]

# If the last chunk is smaller than chunk_size, merge it with the previous chunk
if len(chunks[-1]) < chunk_size:
    chunks[-2].extend(chunks[-1])  # Merge last chunk into the second last chunk
    chunks = chunks[:-1]  # Remove the now empty last chunk

# Process each chunk
for i, chunk in enumerate(chunks):
    print(f"Processing Chunk {i + 1} ({len(chunk)} elements):")

    # Generate content for the current chunk
    response = generate_and_save_csv(data+chunk)

    # Handle None response (i.e., if generation fails or no valid response)
    if response:
        print("Generated response for chunk:", response.text)
    else:
        print(f"No valid response for Chunk {i + 1}. Skipping this chunk.")

    print("-" * 50)

# Ensure lists are of the same length before creating the DataFrame
if len(inputs) == len(outputs) == len(subcategories):
    # Create a dictionary with the data
    data = {
        "Complain": inputs,  # List of user complaints
        "Category": outputs,  # Corresponding categories or errors
        "Subcategory Name": subcategories
    }

    # Create a DataFrame from the dictionary
    dataset = pd.DataFrame(data)

    # Save the DataFrame to a CSV file
#     csv_file_path = "Generate_report_1.csv"
#     dataset.to_csv(csv_file_path, index=False)
#     print(f"CSV file has been saved as {csv_file_path}")
# else:
#     print("Error: Mismatch in data lengths. Cannot create DataFrame.")

# Output the shape of the dataset (for debugging)
print("Dataset shape:", len(inputs))

# %%
# Create the chunks
chunks = [prepare_data[i:i + chunk_size] for i in range(0, total_length, chunk_size)]

# If the last chunk is smaller than 2998, merge it with the previous chunk
if len(chunks[-1]) < chunk_size:
    chunks[-2].extend(chunks[-1])  # Merge last chunk into the second last chunk
    chunks = chunks[:-1]  # Remove the now empty last chunk

# Now, `chunks` will contain only chunks of exactly 2998 elements

# Check if each chunk has exactly 2998 elements
for i, chunk in enumerate(chunks):
    if i < 2:  # Process only the first two chunks
        print(f"Chunk {i+1} ({len(chunk)} elements):")
        # Step 1: Generate the CSV file for the first and second chunk
        generate_and_save_csv(chunk, f"generation_chunk_{i+1}.csv")
        print(chunk)
        print("-" * 50)
    else:
        break  # Stop the loop after processing the first two chunks

print("Inputs:", inputs)
print("Outputs:", outputs)
print("Subcategories:", subcategories)

# Ensure lists are of the same length
if len(inputs) == len(outputs) == len(subcategories):
    # Create a dictionary with the data
    data = {
        "Complain": inputs,  # List of user complaints
        "Category": outputs,  # Corresponding categories or errors
        "Subcategory Name": subcategories
    }

    # Create a DataFrame from the dictionary
    dataset = pd.DataFrame(data)

    # Save the DataFrame to a CSV file
    csv_file_path = "Generate_report_1.csv"
    dataset.to_csv(csv_file_path, index=False)
    print(f"CSV file has been saved as {csv_file_path}")
else:
    print("Error: Mismatch in data lengths. Cannot create DataFrame.")

dataset.shape

# %%
# import re
# import pandas as pd


# # # Lists to store extracted inputs and outputs
# # inputs = []
# # outputs = []
# # subcategories = []

# # # Loop through each JSON-like object
# # for data in json_objects:
# #     # Extract 'user complaint'
# #     input_match = re.search(r'"user complaint": "(.*?)"', data, re.IGNORECASE)
# #     user_complaint = input_match.group(1) if input_match else ""
# #     inputs.append(user_complaint)

# #     # Extract 'error' or 'Category Name'
# #     output_match = re.search(r'(?:"error":| "Category Name":)\s*"(.*?)"', data, re.IGNORECASE)
# #     error_or_category = output_match.group(1) if output_match else ""
# #     outputs.append(error_or_category)

# #     # Extract 'Subcategory Name'
# #     subcategory_match = re.search(r'"Subcategory Name":\s*"(.*?)"', data, re.IGNORECASE)
# #     subcategory_name = subcategory_match.group(1) if subcategory_match else "error unable to identify"
# #     subcategories.append(subcategory_name)

# # Debugging: Check extracted data
# print("Inputs:", inputs)
# print("Outputs:", outputs)
# print("Subcategories:", subcategories)

# # Ensure lists are of the same length
# if len(inputs) == len(outputs) == len(subcategories):
#     # Create a dictionary with the data
#     data = {
#         "Complain": inputs,  # List of user complaints
#         "Category": outputs,  # Corresponding categories or errors
#         "Subcategory Name": subcategories
#     }

#     # Create a DataFrame from the dictionary
#     dataset = pd.DataFrame(data)

#     # Save the DataFrame to a CSV file
#     csv_file_path = "Generate_report_1.csv"
#     dataset.to_csv(csv_file_path, index=False)
#     print(f"CSV file has been saved as {csv_file_path}")
# else:
#     print("Error: Mismatch in data lengths. Cannot create DataFrame.")
# dataset.shape

# %%
import re
import json
parts = [
              {
                "text": "```json\n{\n  \"user complaint\": \"Hello please help me and more like me who are suffering financial frauds from these kinds of applications. I only downloaded the app, and without my consent, they gave me a loan and credited the amount into my account. They are asking for payment even after I\u2019ve paid, and there\u2019s no update in the application. They\u2019ve accessed my contacts and are threatening to call them. I\u2019m frustrated and need help.\",\n  \"error\": \"unable to identify\"\n}\n```\n\n```json\n{\n  \"user complaint\": \"I had continue received random calls and abusive messages in my whatsapp Someone added my number in a unknown facebook group name with  Only Girls  and still getting calls from unknown numbers pls help me and sort out the issue  as soon as possible Thank you\",\n  \"Category Name\": \"Other Cyber Crime\",\n  \"Subcategory Name\": \"Cyber Bullying/Stalking/Sexting\"\n}\n```\n\n```json\n{\n  \"user complaint\": \"The above fraudster is continuously messaging me and Asking me to pay him money or he will send fake  cropped nude photos of me to my other contacts through WhatsApp\\n\\nI am unaware how he has recieved my contacts list from my phone\\n\\nPlease help\",\n  \"Category Name\": \"Other Cyber Crime\",\n  \"Subcategory Name\": \"Cyber Bullying/Stalking/Sexting\"\n}\n```\n\n```json\n{\n  \"user complaint\": \"He is acting like a police and demanding for money by adding sections in the text messages \\nI request you to take an immediate action on him Frequently he is harassing with these messages For reference please find attached files\",\n  \"error\": \"unable to identify\"\n}\n```\n\n```json\n{\n  \"user complaint\": \"In apna Job I have applied for job interview for telecalling and the resource management wrote that twelve hundred will be charged for security amount of laptop and work from home when I have given interview on the given address next day they charged twelve hundred and six hundred more money in the name of insurance after that they have referred me to the job calling there is no work of laptop neither a work from home kindly please take action against it as soon as possible and if possible please help me to recover my financial loss\",\n  \"Category Name\": \"Financial Fraud Crimes\",\n  \"Subcategory Name\": \"Online Job Fraud\"\n}\n```\n\n```json\n{\n  \"user complaint\": \"I received a call from lady stating that she will send new phone of vivo and I received that parcel through post on  th February to Kurnool head post office  where I have not received any mobile\",\n  \"error\": \"unable to identify\"\n}\n```\n\n```json\n{\n  \"user complaint\": \"FRAUD \t UPI PAYTM \\nBANK \tPunjab National Bank including Oriental Bank of Commerce and United Bank of India\t\\nACCOUNT NUMBER  \\nTOTAL AMOUNT  \\nPLEASE HOLD REVERSE TOTAL AMOUNT IN THE COMPLAINT ACCOUNT AND TAKE NECESSARY ACTION\",\n  \"error\": \"unable to identify\"\n}\n```\n\n```json\n{\n  \"user complaint\": \"FINANCIAL FRAUD  RS\",\n  \"error\": \"unable to identify\"\n}\n```\n\n```json\n{\n  \"user complaint\": \"I got the message on Whatsapp to my number The message contains very abusive words This message also includes my friend name and his number in that The same message was forwarded to all other friends also For more details please look into the file attached here Please take action ASAP\",\n  \"Category Name\": \"Other Cyber Crime\",\n  \"Subcategory Name\": \"Cyber Bullying/Stalking/Sexting\"\n}\n```\n\n```json\n{\n  \"user complaint\": \"Details entered in pdf file Person posing as Army officer msg us that he want our place on rent and for that to confirm the account he wants us to transfer Re  in his account and once confirmed he will transfer back\",\n  \"error\": \"unable to identify\"\n}\n```\n\n```json\n{\n  \"user complaint\": \"I received a Whatsapp number in Happn Dating app Then I texted in Whatsapp after that they did a video call asked me to show the face I did then asked me to remove my clothes I did After that they recorded those videos and asking for me to send money I sent  again they are asking me  Kindly help me in this situation Also if needed i can come in person to meet and give more details Please Help\",\n  \"Category Name\": \"Other Cyber Crime\",\n  \"Subcategory Name\": \"Cyber Bullying/Stalking/Sexting\"\n}\n```\n\n```json\n{\n  \"user complaint\": \"Someone changed my email id nd contact number by using anydesk app nd now he had ordered  k product from my account through emi my contact number is nd he changed to this number nd email id also hve been changed now he have access to my account\",\n  \"Category Name\": \"Other Cyber Crime\",\n  \"Subcategory Name\": \"Profile Hacking/Identity Theft\"\n}\n```\n\n```json\n{\n  \"user complaint\": \"I have a friend with whom I made deal to exchange my gaming account of BGMI and he found an account as well for exchange So I shared my login details with him to check the inventory available in my account Suddenly I received a mail that my email id has been changed When I tried contacting him he blocked my call and when I tried calling on WhatsApp he is not answering the call I have spent more than Rs  in my gaming account Request you to please regain my account\",\n  \"Category Name\": \"Other Cyber Crime\",\n  \"Subcategory Name\": \"Profile Hacking/Identity Theft\"\n}\n```\n\n```json\n{\n  \"user complaint\": \"FRAUD THROUGH DebitCredit Card FraudSim Swap Fraud\\n\\nBANKAirtel Payments Bank\\n     \\nACCOUNT NO \\n\\nTOTAL AMOUNT\t\t \t\\n \t\\nPLEASE HOLD REVERSE TOTAL AMOUNT IN THE COMPLAINT ACCOUNT AND TAKE NECESSARY ACTION\",\n  \"Category Name\": \"Financial Fraud Crimes\",\n  \"Subcategory Name\": \"Debit/Credit Card Fraud\"\n}\n```\n\n```json\n{\n  \"user complaint\": \"Received Call from unknown person claimed to be related to his father and said that he had borrowed rs  from his father and want to refund first he confirmed account by sending rs  their after he has theft rs  by  transaction of rs  each call receved from mobile no\",\n  \"Category Name\": \"Financial Fraud Crimes\",\n  \"Subcategory Name\": \"Internet Banking-Related Fraud\"\n}\n```\n\n```json\n{\n  \"user complaint\": \"FRAUD THROUGH UPI Phone Pe\\nBANK BARODA UP GRAMIN BANK\\nACCOUNT NUMBER \\nTOTAL AMOUNT \\nPLEASE HOLDREVERSE TOTAL AMOUNT IN THE COMPLAINT ACCOUNT AND TAKE NECESSARY ACTION \",\n  \"error\": \"unable to identify\"\n}\n```\n\n```json\n{\n  \"user complaint\": \"I wanted to sell my cot on Quikr This person named Ankit Sharma Shop was Interested I am new to Googlepay Voucher payment and he sent me a voucher to pay the amount to my account but the transaction was reverse and he got paid the amount\",\n  \"Category Name\": \"Financial Fraud Crimes\",\n  \"Subcategory Name\": \"Internet Banking-Related Fraud\"\n}\n```\n\n```json\n{\n  \"user complaint\": \"R sir someone call me from  and said that he is my known JAGDISH  and he said some money on my mobile googlepay after that he said a link on my googlpay on rupees  then i click on this link the money is deducted form my account so please solve the same asap\",\n  \"Category Name\": \"Financial Fraud Crimes\",\n  \"Subcategory Name\": \"Internet Banking-Related Fraud\"\n}\n```\n\n```json\n{\n  \"user complaint\": \"I lost amount of  lakh  hazaar rupees\",\n  \"error\": \"unable to identify\"\n}\n```\n\n```json\n{\n  \"user complaint\": \"i received are message from cell no  that my SBI YONO Account has been suspended and to update your PAN card immediately and given a link httspsbipanuponlinepreviewdomaincom at hours according the the link i activate and at result an amount of Rs taken my account pls take necessary action and get my money\",\n  \"Category Name\": \"Financial Fraud Crimes\",\n  \"Subcategory Name\": \"Identity Theft, Spoofing, and Phishing Attacks\"\n}\n```\n\n```json\n{\n  \"user complaint\": \"The issue actually started when I got this email, which at first glance seemed like spam. I usually ignore such things, but for some reason, I opened it this time. Afterward, my phone started freezing, and it wasn\u2019t normal. I thought it was a technical glitch, but now I\u2019m not so sure. Honestly, it\u2019s such a mess, and I don\u2019t even know where to start. I\u2019ve contacted support, but they keep giving me the runaround. The more I tried to fix it, the more problems came up. My bank account was notifiction, and then I got locked out of everything. The worst part is, I don\u2019t even know who to trust anymore. Friends, family, everyone\u2019s acting strange. It\u2019s affecting my relationships and my mental health. Even my laptop isn\u2019t working right anymore. It\u2019s so stange how everything just fell apart after that one email.\",\n  \"Category Name\": \"Other Cyber Crime\",\n  \"Subcategory Name\": \"Malware attacks\"\n}\n```\n\n```json\n{\n  \"user complaint\": \"Regarding job vacancies they call me and ask the money for processing fees including this I share the details of the person whos contact me \\n Amen verma   \\n Nithin   \\n Sachin   \",\n  \"Category Name\": \"Financial Fraud Crimes\",\n  \"Subcategory Name\": \"Online Job Fraud\"\n}\n```\n\n```json\n{\n  \"user complaint\": \"Respected Cyber crime Ghatkopar east Mumbai\\n\\nThis is Irshad Gafur Shaikh I reside in Ghatkopar east with my family and i am responsible citizen of India and my family\\n\\nI would like to highlight you about two fruadulant loan app which are quitely robbing to innocent and family responsible people like me\\n\\n Koko loan\\n\\nI was looking for k then filling my personal details it showed k then i clicked to check tenurity and roi\\n\\nIt directly selected as applied itself and credited into my account of Rs  and repayment amount is showing as k with  days tenurity\\n\\nScreen shots shared for your reference\\n\\n AG Loan\\n\\nI was looking for k loan as per the app given limit for  days tenurity and i applied for the same then next it credited rs  into my bank account as showing repayment of k with  days tenurity\\n\\nScreen shots and recording shared for your reference\\n\\nNone of the above have mentioned contact center or points\\n\\nI tried to contact them also however its all scam\\n\\nI heartly request you to help me out from the same\\n\\nI am from middle class and i already having many family responaiblity\\n\\nI am ready for the same credited amount only but they are not acknowledging that\",\n  \"error\": \"unable to identify\"\n}\n```\n\n```json\n{\n  \"user complaint\": \"nan\",\n  \"error\": \"unable to identify\"\n}\n```\n\n```json\n{\n  \"user complaint\": \"I never imagined something like this could happen to me, especially since I'm so cautious. But then I started noticing that my online activity felt different, slower even. I can't even describe it well because everything seemed normal, except for the fact that I was constantly getting logged out of my accounts. I don't know how, but it\u2019s like they knew everything I was doing, even though I was trying to be careful. It\u2019s terrifying to think about. The more I tried to fix it, the more problems came up. My email was hackd, and then I got locked out of everything. I don\u2019t think I\u2019ve ever felt this violated before. My privacy is completely shattered, and I can\u2019t do anything to make it stop. Even my laptop isn\u2019t working right anymore. It\u2019s so stange how everything just fell apart after that one email.\",\n  \"Category Name\": \"Other Cyber Crime\",\n  \"Subcategory Name\": \"Unauthorized Access/Data Breach\"\n}\n```\n\n```json\n{\n  \"user complaint\": \"Respected Sir\\n\\nA very serious matter I want to inform you Few person running or involve in some very shamefull activities by using few women at many places of kolkata gariahat ballygunge RUBY HOSPITAL BEHIND area KASBA ANANDAPUR QUEST MALL metropolis mall area ACROPOLISMALL area park circus FORUM MALL ELGIN RD Parkstreet MAIDAN AREA esplanade Garia jadavpur BEHALASAKHERBAZAR JOKA BANSDRONI  Rabindrasadanexide area  HARIDEVPUR triangular park lake mall area rashbehari area TOLLYGUNGE THAKURPUKUR BBD BAG DALHOUSIE AREA  and SALTLAKE\\n\\nTheir name \\nSUBHRO SAHA AMLAN DATTA \\nIZAZ AHMED Anirban\\n\\nThey officially work in a insurance office hdfclife  a hindustanpark ab gariahat shopping mall st floor beside of reliance trend building near gariahat more  but outside at several places  they involve in some shamefull activities last years\\n\\nSir a person SUBHRO SAHA forcefully involve few women employee ex FEMALE employee in such shamefull doing\\n\\nAt afternoon evening or after evening or night time they doing this shamefull activities\\n\\nMany innocent people are TRAPPED and suffering in such dirty issue for long time\\nThey are even  to lodge a complain against them because of  threatening and blackmailing ISSUE\\n\\nFrom above  address PLACES and their mobile whatsapp no  you can easily trace and track their all activities You need to investigate Last years detail\\n\\nPlease help\",\n  \"error\": \"unable to identify\"\n}\n```\n\n```json\n{\n  \"user complaint\": \"Online job fraud victim received a link related to online job goes to payment page for processing fee otp entered amount lost cheated Suspect no httpsquikrjobssite\",\n  \"Category Name\": \"Financial Fraud Crimes\",\n  \"Subcategory Name\": \"Online Job Fraud\"\n}\n```\n\n```json\n{\n  \"user complaint\": \"Stop that like fruod for any body do not sher your otp and other ccvcard numberwith other do not resive new number callcastomer family member ferinds with any person do not sher otip and cvv number do not follow any instructions  for calls massages  linkes or other related questions inform the public about  no cheating\",\n  \"error\": \"unable to identify\"\n}\n```\n\n```json\n{\n  \"user complaint\": \"RUPAY KA RECHAREGE PHONE PE SE KARNE KE  UPRANT THODI DER BAD ACCOUNT SE PASE KAT CHUKE THE MESSAGE DWARA PATA CHALA   KAT GYE THE  SE  FEB  BANK BAND HONE SE KO SUCHIT NAHI KARA PYE  FEB KO BANK KO APPLICATION DWARA SUCHIT KIYA   TO YE PASE KAT KARKE GALTI SE NIKALE GAYE HAI KRIPYA ISKI SAHI JACH KAR ACCOUNT ME PASE LAUTANE KI KRIPA KARE\",\n  \"error\": \"unable to identify\"\n}\n```\n\n```json\n{\n  \"user complaint\": \"Hello please help me and more like me who are suffering financial frauds from these kind of applications I only downloaded the app, and without my consent, they gave me a loan and credited the amount into my account. They are asking for payment even after I\u2019ve paid, and there\u2019s no update in the application. They\u2019ve accessed my contacts and are threatening to call them. I\u2019m frustrated and need help.\",\n  \"error\": \"unable to identify\"\n}\n```\n\n```json\n{\n  \"user complaint\": \"Sir\\nI have invested around  lakh in these app from  they are very smart and initially keep their payment system clean with no doubt and from  they creating problem in payments Please help\",\n  \"error\": \"unable to identify\"\n}\n```\n\n```json\n{\n  \"user complaint\": \"This is an unauthorized transaction from an international website Vimeocom I did not receive any prior intimation or authorization mail or notification for the transaction I have blocked the card and raised a complaint with the bank authorities as well Please help\",\n  \"Category Name\": \"Financial Fraud Crimes\",\n  \"Subcategory Name\": \"Debit/Credit Card Fraud\"\n}\n```\n\n```json\n{\n  \"user complaint\": \"A call from    this number was received by me  saying that speaking from indusind bank helping me to make credit card  I received a call at  pm first a lady was speaking then the call was transferred by them to another person  the were having a fake url website made by them only  They make me to open the site and told me to fill the details  i did so  they said that a  rupees otp will come to me as a charges of card  they said a virtual card will be generated of  rupees but the virtual card was not generated they asked me to fill the card number again then  the amount was deducted from my card of  approximately\",\n  \"Category Name\": \"Financial Fraud Crimes\",\n  \"Subcategory Name\": \"Debit/Credit Card Fraud\"\n}\n```\n\n```json\n{\n  \"user complaint\": \"we received call from salomi saying she is custom officer in mumbai one more person is also invoved joshil patel from usa  he was also involved in this they both have created scam for me and looted from me  as an custom duty joshil patel introduced me as my old friend from school he said i will send you some small gift as a friendship we thought its the same parcel but the are now creating story and nobody is giving us details of the parcel its a complete fraud please helo us\",\n  \"error\": \"unable to identify\"\n}\n```\n\n```json\n{\n  \"user complaint\": \"FRAUD THROUGH UPI PHONE PE \\nBANK  STATE BANK OF INDIA \\nACCOUNT NUMBER  \\nTOTAL AMOUNT   \\nPLEASE HOLD  REVERSE TOTAL AMOUNT IN THE COMPLAINT ACCOUNT AND TAKE NECESSARY ACTION\",\n  \"error\": \"unable to identify\"\n}\n```\n\n```json\n{\n  \"user complaint\": \"Citizen Details \\nAddress   Name  BHAGCHAND SAINI  MOBILE NO    DIST  DAUSA    PS SIKANDRA    EMAIL ID  bhagchandmaligmailcom  PINCODE      BANK  STATE BANK OF INDIA AC NO    BRANCH  BHANDARANGE  Citizen Ke sath  Total Fraud Amount   Rs   DATE Jan\\n\\nFraud By    Phone Pay No \\n Transction id  T  UTR      Amount Rs   TIME   PM \\nFrauder Detals  Suchna karta ne bataya ki unke pass unhone no   se call aaya or jankar bankar ki baat ki or paise transfer karva liye \",\n  \"Category Name\": \"Financial Fraud Crimes\",\n  \"Subcategory Name\": \"Internet Banking-Related Fraud\"\n}\n```\n\n```json\n{\n  \"user complaint\": \"FRAUD THROUGH  UPI PHONE PE \\n BANK  UCO BANK \\n ACCOUNT NUMBER  \\n TOTAL AMOUNT  \\n PLEASE HOLD REVERSE TOTAL AMOUNT IN THE COMPLAINT ACCOUNT AND TAKE         NECESSARY ACTION\",\n  \"error\": \"unable to identify\"\n}\n```\n\n```json\n{\n  \"user complaint\": \"FRAUD THROUGH UPI FRAUD GOOGLE PAY\\nBANK  BANK OF BARODA\\nACCOUNT NUMBER  \\nTOTAL AMOUNT   \\n\\nPLEASE HOLD  REVERSE TOTAL AMOUNT IN THE COMPLAINT ACCOUNT AND TAKE NECESSARY ACTION\",\n  \"error\": \"unable to identify\"\n}\n```\n\n```json\n{\n  \"user complaint\": \"Online Frauds   Gaming Fraud  Any Other\\nvictim paid some amount for free fire game access id so later he came to know that it was a fraud\",\n  \"Category Name\": \"Financial Fraud Crimes\",\n  \"Subcategory Name\": \"Online Job Fraud\"\n}\n```\n\n```json\n{\n  \"user complaint\": \"httpswwwxnxxtvvideousapbfuckkkarrr\\n\\n Above link is correct video URl she is one of our relative \\n\\nPlease help her now she is going to get marry other person they are not aware of this information while its recording some malwere functionality has recorded without their permission \\n\\nPlease help her and remove the above video\",\n  \"error\": \"unable to identify\"\n}\n```\n\n```json\n{\n  \"user complaint\": \"His name is Avaneesh Parasar staying in Patna at FLAT   RANJAN PALACE MAGISTRATE COLONY ASHIYANA DIGHA ROAD POST AASHIYANA NAGAR THANA RAJIV NAGAR DIS  PATNA PIN CODE  He took crores of rupees from thousands on people all over india for trading in Bitcoin and promised to return with profit  Capital amount but now he is not returning and arguing and using slangs when we are asking for our own money We are figiting with him from  with him and everytime he keeps giving the reason for each and everything and keeps figting for not retrning the money We are very tired of all this and need to catch him at the earliest Many people are not complaining due to scared of losing their money Even Avaneesh says frankly to complaint to police or move with legal action as police cant do anything to him it seems He is very confident about the police is not going to do anything to him We are struggling lot with him as he is not returning our amount atleast  Request you to spread awareness in media to save many people from him Along with him his partner Sanjana and Anjalli calling many people and inviting to join his online fraud business and they are taking many people money and not returning theier capital also People have to fight to get their own money from him now He also removed from FB group to those people from whomever he took money and not returning He created another new group on Facebook to trap new people and take the money Please catch him asap\",\n  \"error\": \"unable to identify\"\n}\n```\n\n```json\n{\n  \"user complaint\": \"caller has lost  rupees through fraud call\",\n  \"error\": \"unable to identify\"\n}\n```\n\n```json\n{\n  \"user complaint\": \"Payu payments pvt Ltd\\nOnemobiwiksystem pvt Ltd  \\nThese name show in dhany pay transcation  \\n other nb that use my adhar card \\nPlz resolve my problm\\nHe mis use my wallet money\",\n  \"error\": \"unable to identify\"\n}\n```\n\n```json\n{\n  \"user complaint\": \"FRAUD THROUGH UPI \tFRAUD  PHONEPE  \\nBANK  STATE OF INDIA \\nACCOUNT NO     \\nTOTAL AMOUNT \\nPLEASE HOLD REVERSE TOTAL AMOUNT IN THE COMPLAINT ACCOUNT AND TAKE NECESSARY ACTION\",\n  \"error\": \"unable to identify\"\n}\n```\n\n```json\n{\n  \"user complaint\": \"FRAUD THROUGH UPI PHONEPE\\nBANK SBI BANK \\nACCOUNT NO  \\nTOTAL\\nPLEASE HOLD REVERSE TOTAL AMOUNT IN THE \\nCOMPLAINT  ACCOUNT AND TAKE NECESSARY ACTION\",\n  \"error\": \"unable to identify\"\n}\n```\n\n```json\n{\n  \"user complaint\": \"Many fake accounts are created and Im suffering since year vulgar language chatting in Instagram with my friends and family members and they are also suffering by this issue in kindly requesting to you help me its my humble request\",\n  \"Category Name\": \"Other Cyber Crime\",\n  \"Subcategory Name\": \"Fake/Impersonating Profile\"\n}\n```\n\n```json\n{\n  \"user complaint\": \"EMI\",\n  \"error\": \"unable to identify\"\n}\n```\n\n```json\n{\n  \"user complaint\": \"victime online lo olx flat form nandu pulsar bike konali ani search cheyaga fraud star  amount loss ayyaru\",\n  \"error\": \"unable to identify\"\n}\n```\n\n```json\n{\n  \"user complaint\": \"name  gaurav chhangani ne bataya ki mere google pe no  pe  ka link aaya jese hi mene uspe click  kiya mere BOB ac no  se  rupay kat gaye\",\n  \"Category Name\": \"Financial Fraud Crimes\",\n  \"Subcategory Name\": \"Internet Banking-Related Fraud\"\n}\n```\n\n```json\n{\n  \"user complaint\": \"SirMaam \\nThis is my third report on this reporting portal I had conflicts with my boyfriend ex where he caused problems to me and my family In the heat of the moment he threatened me that he will leak my private photos on the internet In the deep shock while I was searching internships on LinkedIn I came across a new account named Abhishek Sharma He manipulated me by reading my face and hand and i spilled the beans about the incident and told me that I was threatened regarding my private pics Though my ex boyfriend didnt do anything but i was mentally disturbed and still am Since December   he has been threatening me and my ex boyfriend that he has hacked his phone and he will leak our pictures He makes new instagram accounts he hacked my exs account he now emails me Alleged Abhishek Sharma also asked me to meet and said he wants my nudes \\n\\nPlease help me I can only provide you with instagram handles and his email I have no information about him but he has all information about me and my ex \\n\\nIts been more than two months now I dont want my family involved Please solve this \\n\\nHe has been calling from different number texting from different accounts hacking our social media accounts says that he has our nudes Please help\",\n  \"Category Name\": \"Other Cyber Crime\",\n  \"Subcategory Name\": \"Cyber Bullying/Stalking/Sexting\"\n}\n```\n\n```json\n{\n  \"user complaint\": \"I want to lodge a complaint about a fraud call that i received on  at around  pm\\n\\nI have received a phone call and the agent said that he is calling from SBI credit card department Then he would have asked for bank details which I refused to provide He put my call on hold several times and asked me to share OTP which I refused to provide again Then I cut his call After that I have downloaded a mini statement which had a deduction of  rupees from my account\",\n  \"Category Name\": \"Financial Fraud Crimes\",\n  \"Subcategory Name\": \"Internet Banking-Related Fraud\"\n}\n```\n\n```json\n{\n  \"user complaint\": \"Job ke liye maine paise bheje the aur mere sath dhokha hua Mai chahta hu ki jisne mere satth dhokha kiya h uske accout block kr diya jaye  Or mera sara paisa wapas kiya jaye  Or mera paisa wapas kr diya jaye  Ku ki mai nhi chahta ki ayasa froud kisse or ke satth ho  Jisse usse presani ho  Or uska account block kiya jaye  Or mera paisa wapas kr diya jaye  Ku ki mai nhi chahta ki ayasa froud kisse or ke satth ho  Jisse usse presani ho  Or uska account block kiya jaye\",\n  \"Category Name\": \"Financial Fraud Crimes\",\n  \"Subcategory Name\": \"Online Job Fraud\"\n}\n```\n\n```json\n{\n  \"user complaint\": \"My friend mentioned something like this happened to them a few months ago, but I thought it was a one-off. Then, suddenly, I got this weird notification asking me to update my password, but the message didn\u2019t look like the usual ones I receive from the app. It looked a bit off. It\u2019s hard to explain, but it felt like someone was inside my account, doing things while I wasn\u2019t even online. The more I tried to fix it, the more problems came up. My work account was recived, and then I got locked out of everything. I feel so helpless, like there\u2019s nothing I can do to fix this. No matter how many times I change my password, it\u2019s like someone\u2019s always one step ahead. Even my tablet isn\u2019t working right anymore. It\u2019s so stange how everything just fell apart after that one email.\",\n  \"Category Name\": \"Other Cyber Crime\",\n  \"Subcategory Name\": \"Unauthorized Access/Data Breach\"\n}\n```\n\n```json\n{\n  \"user complaint\": \"DEBIT CARD FRAUD TOTAL AMOUNT \\nST TRANSACTION IS  RUPEES  DEBITED IN MY ACCOUNT  TRANSACTION ID IS  REF NUMBER \\nND TRANSACTION IS  RUPEES DEBITED IN MY ACCOUNT TRANSACTION ID  REF NUMBER \\nRD TRANSACTION IS  REPEES DEBITED IN MY ACCOUNT TRANSATION ID \\nREF NUMBER \",\n  \"Category Name\": \"Financial Fraud Crimes\",\n  \"Subcategory Name\": \"Debit/Credit Card Fraud\"\n}\n```\n\n```json\n{\n  \"user complaint\": \"This khushi gupta account on facebook share my fake video on messenger to my relative and demand money to me for remove this video She share a fake video merged video to my friends  relatives on facebook and demand money for remove this content\",\n  \"Category Name\": \"Other Cyber Crime\",\n  \"Subcategory Name\": \"Cyber Bullying/Stalking/Sexting\"\n}\n```\n\n```json\n{\n  \"user complaint\": \"I got a message of the link and I clicked and it sent whatsapp contact  then he suggested to telegram and sent a link and said to deposit  and i got  rupees and then he said to deposit  and I got  then he said you should have to complete some orders then he said to deposit  then it goes on to  in total and he said you should complete order that and deposit  in total then in you will get all the amount you deposit in return with commission and i dont have any money whatever I have i deposited where should I have bring that amount of  as iam a student and I am a son of farmer please sir or madam please help me in returning my money please please\",\n  \"error\": \"unable to identify\"\n}\n```\n\n```json\n{\n  \"user complaint\": \"FRAUD THROUGH UPI Fraud\tPHONE PE\\nBANK \tState Bank of India\t\\nACCOUNT  NUMBER  \\nTOTAL AMOUNT  \t\t\\n PLEASE HOLD REVERSE TOTAL AMOUNT IN THE COMPLAINT ACCOUNT AND TAKE NECESSARY \",\n  \"error\": \"unable to identify\"\n}\n```\n\n```json\n{\n  \"user complaint\": \"Received sms and then I had call the number  they told me to download from play store kyc anydesk app I had downloaded then they told to do next and number arrived on the screen they had asked that no I told them  digit no but then I realised that it is a fraud call I had cut the call and informed Vodafone customer care and also informed on police number  they told me file a complaint\",\n  \"Category Name\": \"Other Cyber Crime\",\n  \"Subcategory Name\": \"Profile Hacking/Identity Theft\"\n}\n```\n\n```json\n{\n  \"user complaint\": \"A call was recieved and few instructions were followed The person on the other side asked to upload the picture of the debite card The debit card was scanned and the amount was debited in three transactions The details of two transactions are attacted\",\n  \"Category Name\": \"Financial Fraud Crimes\",\n  \"Subcategory Name\": \"Debit/Credit Card Fraud\"\n}\n```\n\n```json\n{\n  \"user complaint\": \"FRAUD THROUGH UPI PHONE PE Fraud\t\t\\nBANK  AXIS BANK \\nACCOUNT NUMBER  \\nTOTAL AMOUNT  \\nPLEASE HOLD  REVERSE TOTAL AMOUNT IN THE COMPLAINT ACCOUNT AND TAKE NECESSARY ACTION \",\n  \"error\": \"unable to identify\"\n}\n```\n\n```json\n{\n  \"user complaint\": \"My friend mentioned something like this happened to them a few months ago, but I thought it was a one-off. Then, suddenly, I got this weird notification asking me to update my password, but the message didn\u2019t look like the usual ones I receive from the app. It looked a bit off. It\u2019s hard to explain, but it felt like someone was inside my account, doing things while I wasn\u2019t even online. The more I tried to fix it, the more problems came up. My work account was recived, and then I got locked out of everything. I feel so helpless, like there\u2019s nothing I can do to fix this. No matter how many times I change my password, it\u2019s like someone\u2019s always one step ahead. Even my tablet isn\u2019t working right anymore. It\u2019s so stange how everything just fell apart after that one email.\",\n  \"Category Name\": \"Other Cyber Crime\",\n  \"Subcategory Name\": \"Unauthorized Access/Data Breach\"\n}\n```\n\n```json\n{\n  \"user complaint\": \"I placed an order from the website \\nhttpsredmetticom for a smart watchthe amount was debited from my bank accountbut the order was not placed No response from the seller I tried to contact through mail and phone number of the sellerbut there was no response I was able to find similar problems faced by other costumers online This is a fake website I request you to kindly do the needful and help me to get my amount back\",\n  \"error\": \"unable to identify\"\n}\n```\n\n```json\n{\n  \"user complaint\": \"Dear sir\\n        Please stop the fraudulent transaction and refund the amount  in source account\\n Regards \",\n  \"error\": \"unable to identify\"\n}\n```\n\n```json\n{\n  \"user complaint\": \"Dear Sir involve me in business and after update wallet amount  somthing id is blocked and dont give me any update by Call no   and Website is wwwdigiservicetech i have many time call bt not received mymcall\",\n  \"error\": \"unable to identify\"\n}\n```\n\n```json\n{\n  \"user complaint\": \"I have lost my money from my account through upi transaction without informing me and without sending any opt to my register number ii have not sent any money to fraud account i have called my bank and register a complete againt thisbank manager have told that me that they have all the detail about the transaction They told me that my money have been sent to sbi  bank account they have given me that account ifsc code IFSC code of sbi account is SBIN and this account belongs to garena\",\n  \"Category Name\": \"Financial Fraud Crimes\",\n  \"Subcategory Name\": \"Internet Banking-Related Fraud\"\n}\n```\n\n```json\n{\n  \"user complaint\": \"ye log icici bank ki taraf se hr ban kr baccho k sath froud kr krhe h  hum ko phle whatsapp pr interview k lie invite krte h or uske bad ek ya doo bar online webex jaise online meeting valo application pr kisi se hr ban kr bat krte h or fir select kr k direct account details bhej dete h ki isme phle training fee  jma kre jab training suru hogi  jabki aise nhi h training ki fees to bank charge krta h but aise advance m nhi krvata  vo job lagne k bad hmari sallery m se hi har mahine kat leta h thodi thodi kr k\",\n  \"Category Name\": \"Financial Fraud Crimes\",\n  \"Subcategory Name\": \"Online Job Fraud\"\n}\n```\n\n```json\n{\n  \"user complaint\": \"A call received on th Jan to my mobile  from ICICI Bank Call Center No at pm stating that there was a Fraud caught thru Mumbai Cyber Cell team last week by ICICI Bnk which was done by a Bangalore Co and ICICI bnk has got recovery of  customer database where my name was listed The person told he is calling from Credit Card official Dept and this is official call Amount which was hold on ICICI Bank server need to first decline it  then will credit back to my credit card so he took my card details and generated OTP The person told that  amounts will be credited to my credit card in  hours so he asked OTP to decline transactions After that received another call from ICICI Bank LL no at pm stating that earlier call was official call and if you does not get credit within  hours then call on mb no to get the credit I contacted ICICI bank RM and he was following up with internal dept of credit card to know the fact of call Later bank registered complaint on  Jan and after  days informed status that it cannot be reversed as Merchant Rozarpay is not ready to share details of the same I have recorded call of th Jan and recording sent to Sion Police station via email with Online complaint Registered ID  on th Jan Did not got any call for the same ICICI Bank is not ready to hold above both transactions and I need to pay it on due date Kindly help to get the credit back to my credit card\",\n  \"Category Name\": \"Financial Fraud Crimes\",\n  \"Subcategory Name\": \"Debit/Credit Card Fraud\"\n}\n```\n\n```json\n{\n  \"user complaint\": \"They had first called me with  with name shvani freelancer and contacted me from this number many times and asked rs    second time they contacted with  with truecaller name Hr FREELANCER and asked rs   rs  i had all payment They contacted me with whatsaap no\",\n  \"Category Name\": \"Financial Fraud Crimes\",\n  \"Subcategory Name\": \"Online Job Fraud\"\n}\n```\n\n```json\n{\n  \"user"
              }
      ]

conv_to_json=parts[0]["text"]
print(model.count_tokens(conv_to_json))
# json_objects = re.findall(r'\{[^}]*\}', conv_to_json)
# # parsed_data = [json.loads(obj) for obj in json_objects]
# json_objects
# string to json
