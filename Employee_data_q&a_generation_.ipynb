# %%
data =[
  "Below is the provided Employee Information. Use this information exclusively to perform the tasks described below. Do not incorporate any details or assumptions beyond what is provided. Additionally, convert the Employee Information into a contextual paragraph to provide a narrative-style summary of the data.\n\nTask:\nContext Conversion:\nTransform the given Employee Information into a well-structured paragraph that summarizes all key details.\n\nQuestion and Answer Generation:\n\nCreate 20 questions based solely on the provided Employee Information:\nThe first 10 questions should be simple and fact-based.\nThe next 10 questions should be complex, involving combinations of multiple details or requiring a deeper understanding of the data.\nProvide answers directly below each question using only the information in the context.\n\nVariation Requirement:\nWhen new employee information is provided, ensure the structure and phrasing of the questions are similar but not identical to the previous set. Introduce slight variations in phrasing and complexity to avoid repetition.\n\nNote:\nThe model must ensure that all questions and answers are strictly derived from the provided dataset. No external information or assumptions should be included.",
  "input: 3427\tUriah\tBridges\t20-Sep-19\t\tProduction Technician I\tPeter Oneill\turiah.bridges@bilearner.com\tCCDR\tActive\tContract\tZone C\tTemporary\tUnk\t\tProduction       \tFinance & Accounting\t07-10-1969\tMA\tAccounting\tFemale\t34904\tWhite\tWidowed\tFully Meets\t4",
  "output: Employee 3427, Uriah Bridges, a female Production Technician I, was hired on September 20th. Her supervisor is Peter Oneill, and she can be reached at uriah.bridges@bilearner.com. Uriah's employment status is Active and Contractual, temporary, within Zone C. Her employee code is CCDR, and her date of birth is October 7th, 1969. She holds a MA in Accounting, is White and Widowed, lives in zip code 34904, and her performance rating is \"Fully Meets.\" Her secondary department is Finance & Accounting. Her primary department is Production.\n\nSimple Fact-Based Questions:\nWhat is Employee 3427's name?\nAnswer: Uriah Bridges\nWhat is Employee 3427's job title?\nAnswer: Production Technician I\nWhat is Employee 3427's email address?\nAnswer: uriah.bridges@bilearner.com\nWhat is Employee 3427's supervisor's name?\nAnswer: Peter Oneill\nWhat is Employee 3427's employment status?\nAnswer: Active\nWhat is Employee 3427's contract type?\nAnswer: Contract\nIn what zone does Employee 3427 work?\nAnswer: Zone C\nWhat is Employee 3427's employee code?\nAnswer: CCDR\nWhat is Employee 3427's date of birth?\nAnswer: 07-10-1969\nWhat is Employee 3427's primary department?\nAnswer: Production\n\nComplex Questions:\nConsidering both her employment status and contract type, describe Uriah Bridges' current work arrangement.\nAnswer: Uriah Bridges is an active employee on a temporary contract.\nWhat is the combination of Employee 3427's marital status and race?\nAnswer: White and Widowed\nDoes Employee 3427's performance rating align with her active employment status? Explain.\nAnswer: Yes, her \"Fully Meets\" rating indicates satisfactory performance, consistent with her active employment.\nBased on the provided data, what is Uriah Bridges' educational background in relation to her job function?\nAnswer: She has a Master's degree in Accounting, which is relevant to her secondary department in Finance & Accounting.\nWhat is the discrepancy between Uriah's primary and secondary departments and how might this be explained?\nAnswer: Her primary department is Production while her secondary department is Finance and Accounting. This may suggest a role involving both production and financial tasks.\nWhat information is missing regarding the nature of Uriah Bridges' temporary contract?\nAnswer: The duration of her temporary contract is unknown (\"Unk\").\nGiven Employee 3427's hiring date and date of birth, how old was she when she started working at the company?\nAnswer: 50 years old.\nCombining several data points, create a concise professional profile of Uriah Bridges.\nAnswer: Uriah Bridges is a 50-year-old, widowed, white female with a Master's in Accounting who works as a Production Technician I on a temporary contract.\nWhat is the relationship between Employee 3427's zip code and her employment?\nAnswer: The provided zip code (34904) is her residential address and has no direct relation to her employment details.\nWhat aspects of Employee 3427's profile might be relevant to Human Resources planning or performance reviews?\nAnswer: Her performance rating (\"Fully Meets\"), contract type (Temporary), and department assignments are all relevant for HR planning and performance reviews.",
  "input: 3428\tPaula\tSmall\t11-Feb-23\t\tProduction Technician I\tRenee Mccormick\tpaula.small@bilearner.com\tEW\tActive\tContract\tZone A\tPart-Time\tUnk\t\tProduction       \tAerial\t30-08-1965\tMA\tLabor\tMale\t6593\tHispanic\tWidowed\tFully Meets\t3",
  "output: Employee 3428, Paula Small, a male Production Technician I, was hired on February 11th, 2023. His supervisor is Renee Mccormick, and he can be reached at . Paula's employment status is Active and Contractual, part-time, within Zone A. His employee code is EW, and his date of birth is August 30th, 1965. He holds a MA in Labor, is Hispanic and Widowed, lives in zip code 6593, and his performance rating is \"Fully Meets.\" His secondary department is Aerial. His primary department is Production.\n\nSimple Fact-Based Questions:\nWhat is Employee 3428's name?\nAnswer: Paula Small\nWhat is Employee 3428's job title?\nAnswer: Production Technician I\nWhat is Employee 3428's email address?\nAnswer: paula.small@bilearner.com\nWhat is Employee 3428's supervisor's name?\nAnswer: Renee Mccormick\nWhat is Employee 3428's employment status?\nAnswer: Active\nWhat is Employee 3428's contract type?\nAnswer: Contract\nIn what zone does Employee 3428 work?\nAnswer: Zone A\nWhat is Employee 3428's employee code?\nAnswer: EW\nWhat is Employee 3428's date of birth?\nAnswer: 30-08-1965\nWhat is Employee 3428's primary department?\nAnswer: Production\n\nComplex Questions:\nConsidering his employment status, contract type, and work schedule, describe Paula Small's current work arrangement.\nAnswer: Paula Small is an active, part-time employee working under a contract.\nWhat is the combination of Employee 3428's gender and marital status?\nAnswer: Male and Widowed\nDoes Employee 3428's performance rating align with his active employment status? Explain.\nAnswer: Yes, his \"Fully Meets\" rating suggests satisfactory performance, consistent with his active employment status.\nBased on the provided data, what is Paula Small's educational background in relation to his job function?\nAnswer: He has a Master's degree in Labor, which might be tangentially related to production processes but not directly specified.\nWhat is the relationship between Paula Small's primary and secondary departments?\nAnswer: His primary department is Production, and his secondary department is Aerial. The relationship between these departments isn't explicitly defined.\nWhat information is missing concerning the nature of Paula Small's part-time contract?\nAnswer: The specific number of hours worked per week or other details about his part-time arrangement are unspecified.\nGiven Employee 3428's hiring date and date of birth, how old was he when he started working at the company?\nAnswer: 57 years old.\nCombining several data points, create a concise professional profile of Paula Small.\nAnswer: Paula Small is a 57-year-old, widowed Hispanic male with a Master's in Labor who works part-time as a Production Technician I under a contract.\nWhat is the significance of Employee 3428's zip code in relation to his employment?\nAnswer: The provided zip code (6593) is his residential location and has no specified connection to his employment.\nWhat aspects of Employee 3428's profile are significant for Human Resources in terms of workforce planning?\nAnswer: His part-time status, contract type, age, and performance rating are all factors relevant to HR workforce planning.",
  "input: 3429\tEdward\tBuck\t10-Dec-18\t\tArea Sales Manager\tCrystal Walker\tedward.buck@bilearner.com\tPL\tActive\tFull-Time\tZone B\tPart-Time\tUnk\t\tSales\tGeneral - Sga\t06-10-1991\tMA\tAssistant\tMale\t2330\tHispanic\tWidowed\tFully Meets\t4",
  "output: Employee 3429, Edward Buck, a male Area Sales Manager, was hired on December 10th, 2018. His supervisor is Crystal Walker, and he can be reached at edward.buck@bilearner.com. Edward's employment status is Active and Full-Time, but he works part-time hours, within Zone B. His employee code is PL, and his date of birth is October 6th, 1991. He holds a MA in Assistant, is Hispanic and Widowed, lives in zip code 2330, and his performance rating is \"Fully Meets.\" His secondary department is General - Sga. His primary department is Sales.\n\nSimple Fact-Based Questions:\nWhat is Employee 3429's full name?\nAnswer: Edward Buck\nWhat is Edward Buck's job title?\nAnswer: Area Sales Manager\nWhat is Edward Buck's work email address?\nAnswer: edward.buck@bilearner.com\nWho is Edward Buck's direct supervisor?\nAnswer: Crystal Walker\nWhat is Edward Buck's employment status?\nAnswer: Active\nIs Edward Buck a full-time or part-time employee?\nAnswer: Full-Time (but works part-time hours)\nIn which zone does Edward Buck work?\nAnswer: Zone B\nWhat is Edward Buck's employee code?\nAnswer: PL\nWhat is Edward Buck's date of birth?\nAnswer: 06-10-1991\nWhat is Edward Buck's primary department?\nAnswer: Sales\n\ncomplex Questions:\nDescribe the apparent discrepancy in Edward Buck's employment arrangement based on the provided data.\nAnswer: He is listed as a full-time employee but works part-time hours.\nWhat combination of factors describes Edward Buck's demographic profile?\nAnswer: Hispanic, male, and widowed.\nDoes Edward Buck's performance rating support his continued employment? Explain.\nAnswer: Yes, his \"Fully Meets\" rating indicates satisfactory performance.\nBased on the provided information, how relevant is Edward Buck's MA in Assistant to his current role?\nAnswer: The relevance of his MA in Assistant to his Area Sales Manager position is not explicitly stated.\nWhat is the relationship between Edward Buck's primary and secondary departments?\nAnswer: His primary department is Sales, and his secondary department is General - SGA. The exact nature of this relationship is unclear.\nWhat crucial information is missing regarding Edward Buck's part-time work arrangement?\nAnswer: The exact number of hours he works per week is unspecified.\nCalculate Edward Buck's age at the time of his hiring.\nAnswer: 27 years old\nSummarize Edward Buck's professional profile based on the given data.\nAnswer: Edward Buck is a 27-year-old widowed Hispanic male Area Sales Manager who works part-time hours despite being classified as a full-time employee.\nWhat is the significance of Edward Buck's residential zip code (2330) within the context of his employment?\nAnswer: His zip code is his residential location and has no direct relevance to his job description.\nWhich aspects of Edward Buck's employment details would be most relevant for performance management and HR planning?\nAnswer: His performance rating (\"Fully Meets\"), his part-time work arrangement (despite full-time status), and his department assignments are important for performance management and HR planning.",
  "input: 3430\tMichael\tRiordan\t21-Jun-21\t\tArea Sales Manager\tRebekah Wright\tmichael.riordan@bilearner.com\tCCDR\tActive\tContract\tZone A\tFull-Time\tUnk\t\tSales\tFinance & Accounting\t04-04-1998\tND\tClerk\tMale\t58782\tOther\tSingle\tFully Meets\t2",
  "output: Employee 3430, Michael Riordan, a male Area Sales Manager, was hired on June 21st, 2021. His supervisor is Rebekah Wright, and he can be reached at michael.riordan@bilearner.com. Michael's employment status is Active and Contractual, full-time, within Zone A. His employee code is CCDR, and his date of birth is April 4th, 1998. He holds a ND in Clerk, identifies as Other, is Single, lives in zip code 58782, and his performance rating is \"Fully Meets\". His secondary department is Finance & Accounting. His primary department is Sales.\n\nSimple Fact-Based Questions:\nWhat is the employee ID number for Michael Riordan?\nAnswer: 3430\nWhat is Michael Riordan's job title?\nAnswer: Area Sales Manager\nWhat is Michael Riordan's email address?\nAnswer: michael.riordan@bilearner.com\nWho is Michael Riordan's supervisor?\nAnswer: Rebekah Wright\nWhat is Michael Riordan's employment status?\nAnswer: Active\nWhat type of contract does Michael Riordan have?\nAnswer: Contract\nIn which zone does Michael Riordan work?\nAnswer: Zone A\nWhat is Michael Riordan's employee code?\nAnswer: CCDR\nWhat is Michael Riordan's date of birth?\nAnswer: 04-04-1998\nWhat is Michael Riordan's primary department?\nAnswer: Sales\n\nComplex Questions:\nConsidering Michael Riordan's employment status and contract type, describe his current work arrangement.\nAnswer: Michael Riordan is an active, full-time employee working under a contract.\nWhat combination of factors describes Michael Riordan's demographic profile?\nAnswer: Male, single, identifies as \"Other\".\nDoes Michael Riordan's performance rating align with his active employment status? Explain.\nAnswer: Yes, his \"Fully Meets\" rating indicates satisfactory performance, consistent with his active employment.\nBased on the provided data, how relevant is Michael Riordan's ND in Clerk to his current Area Sales Manager role?\nAnswer: The relevance of his ND in Clerk to his Area Sales Manager role is not explicitly stated.\nWhat is the relationship between Michael Riordan's primary and secondary departments?\nAnswer: His primary department is Sales, and his secondary department is Finance & Accounting. The exact nature of this relationship is not specified.\nWhat significant information is missing regarding the details of Michael Riordan's contract?\nAnswer: The duration or specific terms of his contract are unspecified.\nHow old was Michael Riordan when he was hired?\nAnswer: 23 years old\nCreate a concise professional profile of Michael Riordan based on the available information.\nAnswer: Michael Riordan is a 23-year-old single male, identifying as \"Other,\" who works as a full-time Area Sales Manager under a contract, with a secondary assignment in Finance & Accounting.\nWhat is the significance of Michael Riordan's residential zip code (58782) in relation to his employment?\nAnswer: His zip code is his residential location and has no stated connection to his employment.\nWhich aspects of Michael Riordan's profile are most relevant for performance reviews and future HR planning?\nAnswer: His performance rating (\"Fully Meets\"), contract type, department assignments, and age are relevant factors for performance reviews and future HR planning.",
  "input: 3431\tJasmine\tOnque\t29-Jun-19\t\tArea Sales Manager\tJason Kim\tjasmine.onque@bilearner.com\tTNS\tActive\tContract\tZone A\tTemporary\tUnk\t\tSales\tGeneral - Con\t29-08-1969\tFL\tLaborer\tFemale\t33174\tOther\tMarried\tFully Meets\t3",
  "output: Employee 3431, Jasmine Onque, a female Area Sales Manager, was hired on June 29th, 2019. Her supervisor is Jason Kim, and she can be reached at jasmine.onque@bilearner.com. Jasmine's employment status is Active and Contractual, temporary, within Zone A. Her employee code is TNS, and her date of birth is August 29th, 1969. She holds a FL in Laborer, identifies as Other, is Married, lives in zip code 33174, and her performance rating is \"Fully Meets\". Her secondary department is General - Con. Her primary department is Sales.\n\nSimple Fact-Based Questions:\nWhat is the employee number assigned to Jasmine Onque?\nAnswer: 3431\nWhat is Jasmine Onque's current job title?\nAnswer: Area Sales Manager\nWhat is the email address to contact Jasmine Onque?\nAnswer: jasmine.onque@bilearner.com\nWho is Jasmine Onque's direct supervisor?\nAnswer: Jason Kim\nWhat is Jasmine Onque's current employment status?\nAnswer: Active\nWhat type of contract is Jasmine Onque employed under?\nAnswer: Contract\nIn which work zone is Jasmine Onque assigned?\nAnswer: Zone A\nWhat is Jasmine Onque's employee code?\nAnswer: TNS\nWhat is Jasmine Onque's date of birth?\nAnswer: 29-08-1969\nWhat is Jasmine Onque's primary department?\nAnswer: Sales\n\nComplex Questions:\nConsidering her employment status and contract type, describe Jasmine Onque's current work arrangement.\nAnswer: Jasmine Onque is an active employee working on a temporary contract.\nWhat combination of factors describes Jasmine Onque's demographic profile?\nAnswer: Female, married, identifies as \"Other\".\nDoes Jasmine Onque's performance rating support her continued employment? Explain.\nAnswer: Yes, her \"Fully Meets\" rating suggests satisfactory performance, consistent with her active employment status.\nBased on the information provided, how relevant is Jasmine Onque's FL in Laborer to her current role as Area Sales Manager?\nAnswer: The relevance of her FL in Laborer to her Area Sales Manager role is not explicitly stated.\nWhat is the relationship between Jasmine Onque's primary and secondary departments?\nAnswer: Her primary department is Sales, and her secondary department is General - Con. The exact nature of this relationship is not specified.\nAnswer: The duration of her temporary contract is unspecified (\"Unk\").\nHow old was Jasmine Onque when she was hired for her current position?\nAnswer: 49 years old\nSummarize Jasmine Onque's professional profile based on the provided data.\nAnswer: Jasmine Onque is a 49-year-old married female, identifying as \"Other,\" who works as an Area Sales Manager under a temporary contract.\nWhat is the significance of Jasmine Onque's residential zip code (33174) within the context of her employment?\nAnswer: Her zip code is her residential location and has no stated connection to her employment.\nWhich aspects of Jasmine Onque's employment details would be most relevant for performance management and HR planning?\nAnswer: Her performance rating (\"Fully Meets\"), contract type (temporary), department assignments, and age are relevant for performance management and HR planning.",
  "input: 3432\tMaruk\tFraval\t17-Jan-20\t\tArea Sales Manager\tSheri Campos\tmaruk.fraval@bilearner.com\tBPC\tActive\tContract\tZone B\tFull-Time\tUnk\t\tSales\tField Operations\t03-04-1949\tCT\tDriver\tMale\t6050\tBlack\tMarried\tFully Meets\t3",
  "output: Employee 3432, Maruk Fraval, a male Area Sales Manager, was hired on January 17th, 2020. His supervisor is Sheri Campos, and he can be reached at maruk.fraval@bilearner.com. Maruk's employment status is Active and Contractual, full-time, within Zone B. His employee code is BPC, and his date of birth is April 3rd, 1949. He holds a CT in Driver, is Black and Married, lives in zip code 6050, and his performance rating is \"Fully Meets\". His secondary department is Field Operations. His primary department is Sales.\n\nSimple Fact-Based Questions:\nWhat is the employee ID number for Maruk Fraval?\nAnswer: 3432\nWhat is Maruk Fraval's job title?\nAnswer: Area Sales Manager\nWhat is Maruk Fraval's work email address?Answer: maruk.fraval@bilearner.comWho is Maruk Fraval's direct supervisor?\nAnswer: Sheri Campos\nWhat is Maruk Fraval's current employment\nstatus?\nAnswer: Active\nWhat type of contract does Maruk Fraval have?\nAnswer: Contract\nIn which work zone is Maruk Fraval assigned?\nAnswer: Zone B\nWhat is Maruk Fraval's employee code?\nAnswer: BPC\nWhat is Maruk Fraval's date of birth?\nAnswer: 03-04-1949\nWhat is Maruk Fraval's primary department?Answer:Sales\n\nComplex Questions:\n\n\nDescribe Maruk Fraval's\ncurrent work arrangement based on his employment status and contract type.\nAnswer:Maruk Fraval is an active, full-time employee working under a contract.\nWhat combination of factors describes Maruk Fraval's demographic profile?\nAnswer: Male, Black, and married.\nDoes Maruk Fraval's performance rating indicate\nsatisfactory performance? Explain.\nAnswer: Yes, his \"Fully Meets\" rating indicates satisfactory performance, consistent with his active employment.\nBased on the provided information, how relevant is Maruk Fraval's CT in Driver to his current role as Area Sales Manager?\nAnswer: The relevance of his CT in Driver to his Area Sales Manager role is not explicitly stated.\nWhat is the relationship between Maruk Fraval's primary and secondary departments?\nAnswer: His primary department is Sales, and his\nsecondary department is Field Operations. The exact nature of this relationship is not specified.\nWhat crucial information is missing regarding the specific terms of Maruk Fraval's contract?Answer: The duration or specific terms of his\ncontract are unspecified.\nHow old was Maruk Fraval when he was hired for his current position?\nAnswer: 70 years old\nCreate a concise professional profile of\nMaruk Fraval based on the available information.\nAnswer: Answer: Maruk Fraval is a 70-year-old married Black male who works as a full-time Area Sales Manager under a contract, with a secondary assignment in Field Operations.\nWhat is the significance of Maruk Fraval's residential zip code (6050) in relation to his employment?\nAnswer: His zip code is his residential location and has no stated connection to his employment.\nWhich aspects of Maruk Fraval's employment details would be most relevant for performance management and HR planning?\nAnswer: His performance rating (\"Fully Meets\"), contract type, department assignments, and age are relevant for performance management and HR planning.",
  "input: 3433\tLatia\tCosta\t06-Apr-22\t03-Jul-23\tArea Sales Manager\tJacob Braun\tlatia.costa@bilearner.com\tWBL\tActive\tFull-Time\tZone B\tTemporary\tInvoluntary\tMe see picture nature degree benefit.\tSales\tGeneral - Eng\t01-07-1942\tCA\tTechnician\tFemale\t90007\tHispanic\tDivorced\tExceeds\t4",
  "output: Employee 3433, Latia Costa, a female Area Sales Manager, was hired on April 6th, 2022, and her last day of employment was July 3rd, 2023. Her supervisor was Jacob Braun, and she could be reached at latia.costa@bilearner.com. Latia's employment status was Active and Full-Time, temporary, involuntary termination, within Zone B. Her employee code is WBL, and her date of birth is July 1st, 1942. She holds a CA in Technician, is Hispanic and Divorced, lives in zip code 90007, and her performance rating is \"Exceeds\". Her secondary department is General - Eng. Her primary department is Sales. The reason for her involuntary termination is noted as \"Me see picture nature degree benefit.\"\n\nSimple Fact-Based Questions:\nWhat is the employee ID number for Latia Costa?\nAnswer: 3433\nWhat was Latia Costa's job title?\nAnswer: Area Sales Manager\nWhat was Latia Costa's work email address?\nAnswer:  latia.costa@bilearner.com\nWho was Latia Costa's direct supervisor?\nAnswer: Jacob Braun\nWhat was Latia Costa's employment status at the time of her termination?\nAnswer: Active\nWhat type of employment was Latia Costa's?\nAnswer: Full-Time\nIn which work zone was Latia Costa assigned?\nAnswer: Zone B\nWhat is Latia Costa's employee code?\nAnswer: WBL\nWhat is Latia Costa's date of birth?\nAnswer: 01-07-1942\n\nComplex Questions:\nDescribe Latia Costa's employment arrangement, including its termination.\nAnswer: Latia Costa was a full-time, temporary employee whose employment was involuntarily terminated.\nWhat combination of factors describes Latia Costa's demographic profile?\nAnswer: Female, Hispanic, and divorced.\nDid Latia Costa's performance rating contribute to her termination? Explain.\nAnswer: No, her \"Exceeds\" rating suggests strong performance, contradicting a performance-based termination.\nAnswer: The relevance of her CA in Technician to her Area Sales Manager role is not explicitly stated.\nWhat is the relationship between Latia Costa's primary and secondary departments?\nAnswer: Her primary department is Sales, and her secondary department is General - Eng. The exact nature of this relationship is not specified.\nWhat information is unclear regarding the reason for Latia Costa's involuntary termination?\nAnswer: The reason \"Me see picture nature degree benefit\" is unclear and requires further explanation.\nHow old was Latia Costa when her employment ended?\nAnswer: 81 years old\nSummarize Latia Costa's professional profile, including her termination.\nAnswer: Latia Costa was an 81-year-old divorced Hispanic female Area Sales Manager who was involuntarily terminated from her full-time, temporary position.\nWhat is the significance of Latia Costa's residential zip code (90007) in relation to her employment?\nAnswer: Her zip code is her residential location and has no stated connection to her employment.\nWhich aspects of Latia Costa's employment details would be most relevant for exit interviews and HR record-keeping?\nAnswer: Her performance rating (\"Exceeds\"), reason for termination (\"Me see picture nature degree benefit.\"), contract type (temporary), and department assignments are all relevant for exit interviews and HR record-keeping.",
  "input: 3434\tSharlene\tTerry\t06-Nov-20\t29-Jan-23\tArea Sales Manager\tTracy Marquez\tsharlene.terry@bilearner.com\tCCDR\tActive\tContract\tZone C\tFull-Time\tInvoluntary\tBlue community type skill story.\tSales\tEngineers\t07-03-1957\tOR\tEngineer\tFemale\t97756\tWhite\tDivorced\tFully Meets\t2",
  "output: Employee 3434, Sharlene Terry, a female Area Sales Manager, was hired on November 6th, 2020, and her last day of employment was January 29th, 2023. Her supervisor was Tracy Marquez, and she could be reached at sharlene.terry@bilearner.com. Sharlene's employment status was Active and Contractual, full-time, involuntary termination, within Zone C. Her employee code is CCDR, and her date of birth is March 7th, 1957. She holds an OR in Engineer, is White and Divorced, lives in zip code 97756, and her performance rating is \"Fully Meets\". Her secondary department is Engineers. Her primary department is Sales. The reason for her involuntary termination is noted as \"Blue community type skill story.\"\n\nSimple Fact-Based Questions:\nWhat is Sharlene Terry's employee ID number?\nAnswer: 3434\nWhat was Sharlene Terry's job title?\nWhat was Sharlene Terry's work email address?\nAnswer: sharlene.terry@bilearner.com\nWho was Sharlene Terry's direct supervisor?\nAnswer: Tracy Marquez\nWhat was Sharlene Terry's employment status at the time of her termination?\nAnswer: Active\nWhat type of contract did Sharlene Terry have?\nAnswer: Contract\nIn which work zone was Sharlene Terry assigned?\nAnswer: Zone C\nWhat is Sharlene Terry's employee code?\nAnswer: CCDR\nWhat is Sharlene Terry's date of birth?\nAnswer: 07-03-1957\nWhat is Sharlene Terry's primary department?\nAnswer: Sales\n\nComplex Questions:\nDescribe Sharlene Terry's employment arrangement, including its termination.\nAnswer: Sharlene Terry was a full-time employee under a contract whose employment was involuntarily terminated.\nWhat combination of factors describes Sharlene Terry's demographic profile?\nAnswer: Female, White, and divorced.\nDoes Sharlene Terry's performance rating suggest a performance-based termination? Explain.\nAnswer: No, her \"Fully Meets\" rating does not indicate poor performance as a reason for termination.\nBased on the provided information, how relevant is Sharlene Terry's OR in Engineer to her role as Area Sales Manager?\nAnswer: The relevance of her OR in Engineer to her Area Sales Manager role is not explicitly stated.\nWhat is the relationship between Sharlene Terry's primary and secondary departments?\nAnswer: Her primary department is Sales, and her secondary department is Engineers. The exact nature of this relationship is not specified.What information is unclear regarding the reason for Sharlene Terry's involuntary termination?\nAnswer: The reason \"Blue community type skill story\" is vague and requires further explanation.\nHow old was Sharlene Terry when her employment ended?\nAnswer: 65 years old\nSummarize Sharlene Terry's professional profile, including her termination.\nAnswer: Sharlene Terry was a 65-year-old divorced White female Area Sales Manager who was involuntarily terminated from her full-time contract position.\nWhat is the significance of Sharlene Terry's residential zip code (97756) in relation to her employment?\nAnswer: Her zip code is her residential location and has no stated connection to her employment.\nWhich aspects of Sharlene Terry's employment details would be most relevant for exit interviews and HR record-keeping?\nAnswer: Her performance rating (\"Fully Meets\"), reason for termination (\"Blue community type skill story\"), contract type, and department assignments are all relevant for exit interviews and HR record-keeping.",
  "input: 3435\tJac\tMcKinzie\t18-Aug-18\t\tArea Sales Manager\tSharon Becker\tjac.mckinzie@bilearner.com\tNEL\tActive\tContract\tZone B\tPart-Time\tUnk\t\tSales\tExecutive\t15-05-1974\tTX\tExecutive Assistant\tMale\t78789\tBlack\tWidowed\tExceeds\t3",
  "output: Employee 3435, Jac McKinzie, a male Area Sales Manager, was hired on August 18th, 2018. His supervisor is Sharon Becker, and he can be reached at jac.mckinzie@bilearner.com. Jac's employment status is Active and Contractual, part-time, within Zone B. His employee code is NEL, and his date of birth is May 15th, 1974. He holds a TX in Executive Assistant, is Black and Widowed, lives in zip code 78789, and his performance rating is \"Exceeds\". His secondary department is Executive. His primary department is Sales.\n\nSimple Fact-Based Questions:\nWhat is Jac McKinzie's employee identification number?\nAnswer: 3435\nWhat is Jac McKinzie's job title?\nAnswer: Area Sales Manager\nWhat is Jac McKinzie's work email address?\nAnswer: jac.mckinzie@bilearner.com\nWho is Jac McKinzie's direct supervisor?\nAnswer: Sharon Becker\nWhat is Jac McKinzie's current employment status?\nAnswer: Active\nWhat type of contract does Jac McKinzie have?\nAnswer: Contract\nIn which work zone is Jac McKinzie assigned?\nAnswer: Zone B\nWhat is Jac McKinzie's employee code?\nAnswer: NEL\nWhat is Jac McKinzie's date of birth?\nAnswer: 15-05-1974\nWhat is Jac McKinzie's primary department?\nAnswer: Sales\n\nComplex Questions:\nDescribe Jac McKinzie's current work arrangement based on his employment status and work schedule.\nAnswer: Jac McKinzie is an active, part-time employee working under a contract.\nWhat combination of factors describes Jac McKinzie's demographic profile?\nAnswer: Male, Black, and widowed.\nDoes Jac McKinzie's performance rating suggest he is a valuable employee? Explain.\nAnswer: Yes, his \"Exceeds\" rating indicates strong performance and makes him a valuable employee.\nBased on the provided information, how relevant is Jac McKinzie's TX in Executive Assistant to his current role as Area Sales Manager?\nAnswer: The relevance of his TX in Executive Assistant to his Area Sales Manager role is not explicitly stated.\nWhat is the relationship between Jac McKinzie's primary and secondary departments?\nAnswer: His primary department is Sales, and his secondary department is Executive. The exact nature of this relationship is not specified.\nWhat crucial information is missing regarding the specifics of Jac McKinzie's part-time contract?\nAnswer: The exact number of hours he works per week or other details about his part-time arrangement are unspecified.\nHow old was Jac McKinzie when he was hired for his current position?\nAnswer: 44 years old\nSummarize Jac McKinzie's professional profile based on the available information.\nAnswer: Jac McKinzie is a 44-year-old widowed Black male who works part-time as an Area Sales Manager under a contract, with a secondary assignment in the Executive department.\nWhat is the significance of Jac McKinzie's residential zip code (78789) in relation to his employment?\nAnswer: His zip code is his residential location and has no stated connection to his employment.\nWhich aspects of Jac McKinzie's employment details would be most relevant for performance reviews and future HR planning?\nAnswer: His performance rating (\"Exceeds\"), contract type, part-time status, department assignments, and age are relevant for performance reviews and future HR planning.",
  "input: 3436\tJoseph\tMartins\t21-Jan-22\t29-Jun-23\tArea Sales Manager\tGeorge Jenkins\tjoseph.martins@bilearner.com\tBPC\tActive\tPart-Time\tZone B\tTemporary\tResignation\tSummer personal bag.\tSales\tEngineers\t11-11-1949\tTX\tEngineer\tMale\t78207\tAsian\tWidowed\tFully Meets\t5",
  "output: Employee 3436, Joseph Martins, a male Area Sales Manager, was hired on January 21st, 2022, and his last day of employment was June 29th, 2023. His supervisor was George Jenkins, and he could be reached at joseph.martins@bilearner.com. Joseph's employment status was Active and Part-Time, temporary, resignation, within Zone B. His employee code is BPC, and his date of birth is November 11th, 1949. He holds a TX in Engineer, is Asian and Widowed, lives in zip code 78207, and his performance rating is \"Fully Meets\". His secondary department is Engineers. His primary department is Sales. The reason for his resignation is noted as \"Summer personal bag.\"\n\nSimple Fact-Based Questions:\nWhat is Joseph Martins' employee identification number?\nAnswer: 3436\nWhat was Joseph Martins' job title?\nAnswer: Area Sales Manager\nWhat was Joseph Martins' work email address?\nAnswer: joseph.martins@bilearner.com\nWho was Joseph Martins' direct supervisor?\nAnswer: George Jenkins\nWhat was Joseph Martins' employment status at the time of his resignation?\nAnswer: Active\nWhat type of employment did Joseph Martins have?\nAnswer: Part-Time\nIn which work zone was Joseph Martins assigned?\nAnswer: Zone B\nWhat is Joseph Martins' employee code?\nAnswer: BPC\nWhat is Joseph Martins' date of birth?\nAnswer: 11-11-1949\nWhat is Joseph Martins' primary department?\nAnswer: Sales\n\nComplex Questions:\nDescribe Joseph Martins' employment arrangement, including its termination..\nAnswer: Joseph Martins was a part-time, temporary employee who resigned from his position.\nWhat combination of factors describes Joseph Martins' demographic profile?\nAnswer: Male, Asian, and widowed.\nDoes Joseph Martins' performance rating suggest any issues that led to his resignation? Explain.\nAnswer: No, his \"Fully Meets\" rating suggests satisfactory performance, indicating that his resignation was likely not performance-related.\nBased on the provided information, how relevant is Joseph Martins' TX in Engineer to his role as Area Sales Manager?\nAnswer: The relevance of his TX in Engineer to his Area Sales Manager role is not explicitly stated.\nWhat is the relationship between Joseph Martins' primary and secondary departments?\nAnswer: His primary department is Sales, and his secondary department is Engineers. The exact nature of this relationship is not specified.\nWhat information is unclear regarding the reason for Joseph Martins' resignation?\nAnswer: The reason \"Summer personal bag\" is vague and requires further explanation.\nHow old was Joseph Martins when he resigned from his position?\nAnswer: 73 years old\nSummarize Joseph Martins' professional profile, including his resignation.\nAnswer: Joseph Martins was a 73-year-old widowed Asian male Area Sales Manager who resigned from his part-time, temporary position.\nWhat is the significance of Joseph Martins' residential zip code (78207) in relation to his employment?\nAnswer: His zip code is his residential location and has no stated connection to his employment.\nWhich aspects of Joseph Martins' employment details would be most relevant for exit interviews and HR record-keeping?\nAnswer: His performance rating (\"Fully Meets\"), reason for termination (\"Summer personal bag\"), employment type (part-time, temporary), and department assignments are all relevant for exit interviews and HR record-keeping.",
]

# %%
prompt= """"
### Instructions:
Below is the Employee Information provided. Use only this data to perform the tasks outlined below. Do not include external information, assumptions, or unrelated details. Follow the specified format and ensure all outputs align with the given requirements.

---
#### Question and Answer Generation:
1. Generate **20 questions and answers** strictly based on the provided Employee Information:
   - **First 10 questions**: Create simple, fact-based questions focusing on individual attributes (e.g., name, role, department).
   - **Next 10 questions**: Formulate more complex, logic-based questions that involve combining multiple data points or require deeper contextual understanding.

2. **Variation Requirement**:
   - Each set of questions should be unique and vary based on the context. Avoid reusing the same phrasing, structure, or logic between different datasets.
   - For example, questions for one Employee Information dataset should differ in phrasing, focus, or complexity from those generated for another dataset, while still adhering to the structure.

3. **Output Format**:
   Every question and answer pair must follow this exact structure:


#### Guidelines for Variation:
- Use synonyms and rephrasing to create diversity (e.g., "What is the employee's role?" vs. "Which position does the employee hold?").
- Introduce logical relationships for complex questions, such as connections between the employee's department, job title, and contract type.
- Adjust question focus based on unique aspects of the dataset, such as demographics, employment status, or contract details.

---

### Example Output:

#### Context Conversion:
Input Data:
[Insert Employee Information]

Context Paragraph:
[Insert narrative-style summary of the Employee Information.]

---

#### Example Questions and Answers:

1. Question: What is the employee's full name?
   Answer: [Insert Answer]

2. Question: On which date did the employee join the company?
   Answer: [Insert Answer]

3. Question: What is the employee's email address?
   Answer: [Insert Answer]

...

11. Question: How does the employee's job title align with their department?
    Answer: [Insert Answer]

12. Question: What relationship exists between the employee's contract type and their employment status?
    Answer: [Insert Answer]

...

---

### Summary of Requirements:
- **Strict Adherence to Format**: Follow the given question and answer structure without deviation.
- **Contextual Variation**: Ensure every set of questions introduces fresh phrasing and complexity, avoiding redundancy across datasets.
- **Focus on Logic**: For complex questions, establish meaningful relationships between data points to enhance the dataset's informative value.
- **Dataset Diversity**: Prioritize variety in the questions to enrich the dataset for training and fine-tuning purposes.


"""

# %%
datastring = """"""
for i in data[:5]:
  datastring += i +"\n"

# %%
print(datastring)

# %%
import pandas as pd
dataset = pd.read_csv("/content/final_employee_copy.csv")

dataset_from_1500th_row = dataset[2400:]

print(dataset_from_1500th_row)
# Out:
#                                                 Context
# 1600  Liam Figueroa, identified by Employee ID 2027,...
# 1601  Linda Combs, identified by Employee ID 2028, w...
# 1602  Marilyn Moss, identified by Employee ID 2029, ...
# 1603  Yuliana Nelson, identified by Employee ID 2030...
# 1604  August Wiley, identified by Employee ID 2031, ...
# ...                                                 ...
# 1995  Rigoberto Gibson, identified by Employee ID 24...
# 1996  Yael Garcia, identified by Employee ID 2423, i...
# 1997  Jonathon Montes, identified by Employee ID 242...
# 1998  Alexzander Guzman, identified by Employee ID 2...
# 1999  Gunnar Gray, identified by Employee ID 2426, i...
#
# [400 rows x 1 columns]

# %%
dataset[:10]
# Out:
#                                              Context
# 0  Uriah Bridges, identified by Employee ID 3427,...
# 1  Paula Small, identified by Employee ID 3428, i...
# 2  Edward Buck, identified by Employee ID 3429, i...
# 3  Michael Riordan, identified by Employee ID 343...
# 4  Jasmine Onque, identified by Employee ID 3431,...
# 5  Maruk Fraval, identified by Employee ID 3432, ...
# 6  Latia Costa, identified by Employee ID 3433, i...
# 7  Sharlene Terry, identified by Employee ID 3434...
# 8  Jac McKinzie, identified by Employee ID 3435, ...
# 9  Joseph Martins, identified by Employee ID 3436...

# %%
import os
import google.generativeai as genai

genai.configure(api_key="AIzaSyAOhqTUmV-wXmPTTq4ukfDil5rTkgIdf2I")

# Create the model
generation_config = {
  "temperature": 1,
  "top_p": 0.95,
  "top_k": 40,
  "max_output_tokens": 8192,
  "response_mime_type": "text/plain",
}

model = genai.GenerativeModel(
  model_name="gemini-1.5-flash",
  generation_config=generation_config,
)

# %%
dataset_from_1500th_row = dataset_from_1500th_row.copy()

# %%
# Define the function to generate text using the model
def generate_text(context):
     try:

        context = prompt + '\n' + context

        # Generate content from the model
        response = model.generate_content(context)
        print(response.text + "\n")
        print(f"--------------------")
        return response.text  # Access the text from the response object
     except Exception as e:
        # Handle exceptions and log errors
        print(f"Error processing context: {context}, Error: {e}")
        return None  # Return None or an empty string for failed attempts

for index, row in dataset_from_1500th_row.iterrows():
    dataset_from_1500th_row.loc[index, 'Generated Text'] = generate_text(row['Context'])

    if index % 100 == 0:
        # Save only up to the current index
        dataset_from_1500th_row.iloc[:index+1].to_csv(f"output_in_progress{index}.csv", index=False)
        print(f"Saved progress at row {index}.")
# Out:
# Streaming output truncated to the last 5000 lines.
#
# 2. Question: What is Emilio Pierce's job title?
#    Answer: Production Technician I
#
# 3. Question: In what department did Emilio Pierce work?
#    Answer: Production Department
#
# 4. Question: What was Emilio Pierce's employment type?
#    Answer: Part-time
#
# 5. Question: What was Emilio Pierce's contract classification?
#    Answer: Temporary
#
# 6. Question: Who supervised Emilio Pierce?
#    Answer: Cristina Davis
#
# 7. Question: What is Emilio Pierce's location code?
#    Answer: 65114
#
# 8. Question: What is Emilio's marital status?
#    Answer: Widowed
#
# 9. Question: What is Emilio Pierce's ethnicity?
#    Answer: Other
#
# 10. Question: What pay zone did Emilio Pierce belong to?
#    Answer: Pay Zone B
#
#
# 11. Question:  Considering Emilio Pierce's job title and department, what can be inferred about their primary responsibilities?
# ...

# %%
for i in dataset['Generated Text']:
  print(i)

# %%
dataset.to_csv("final_3452.csv",index=False)

# %%
dataset.to_csv("Instruction_tuned_employee_dataset.csv",index=False)
